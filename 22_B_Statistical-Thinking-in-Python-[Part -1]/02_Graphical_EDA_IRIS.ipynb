# %% [markdown]
# <a href="https://colab.research.google.com/github/mohd-faizy/CAREER-TRACK-Data-Scientist-with-Python/blob/main/02_Graphical_EDA_IRIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# <strong>
#     <h1 align='center'>Graphical exploratory data analysis [Iris Dataset]
# </h1>
# </strong>
#
# ---

# %% [markdown]
# ### Clone the repository

# %%
! git clone https://github.com/mohd-faizy/CAREER-TRACK-Data-Scientist-with-Python.git
# Out:
# Cloning into 'CAREER-TRACK-Data-Scientist-with-Python'...
# remote: Enumerating objects: 44, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 1901 (delta 21), reused 28 (delta 9), pack-reused 1857
# Receiving objects: 100% (1901/1901), 200.33 MiB | 32.17 MiB/s, done.
# Resolving deltas: 100% (673/673), done.
# Checking out files: 100% (821/821), done.

# %% [markdown]
# ### Change the current working directory

# %%
# import os module 
import os 
   
# to specified path 
os.chdir('/content/CAREER-TRACK-Data-Scientist-with-Python/22_Statistical-Thinking-in-Python-[Part -1]/_datasets') 
  
# varify the path using getcwd() 
cwd = os.getcwd() 
  
# print the current directory 
print("Current working directory is:", cwd)
# Out:
# Current working directory is: /content/CAREER-TRACK-Data-Scientist-with-Python/22_Statistical-Thinking-in-Python-[Part -1]/_datasets

# %%
ls
# Out:
# 2008_all_states.csv    belmont.csv  michelson_speed_of_light.csv
# 2008_swing_states.csv  iris.csv

# %% [markdown]
# ## __1 Exploratory data analysis (EDA)__
#
# __John Tukey's Comments on EDA -:__ "Often times **EDA** is too time consuming, so it is better to jump right in and do our **hypothesis** tests."
#
# That statement is pretty absurd. If we don't have time to do EDA, we really don't have time to do **hypothesis** tests. And we should always do **EDA first**.
#
# __“Exploratory data analysis can never be the whole story, but nothing else can serve as the foundation stone.”__ — _John Tukey_
#
# <p align='center'>
#   <a href="#">
#     <img src='https://miro.medium.com/max/900/1*vJULpN2xQfyVsvTVW-JSkA.png'>
#   </a>
# </p>

# %% [markdown]
# ### Plotting a **histogram** of iris data

# %% [markdown]
# For the exercises in this section, you will use a classic data set collected by botanist Edward Anderson and made famous by Ronald Fisher, one of the most prolific statisticians in history. Anderson carefully measured the anatomical properties of samples of three different species of iris,**Iris setosa, Iris versicolor, and Iris virginica.**
#
# The full data set is available [as part of scikit-learn](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_iris.html). Here, we will work with his measurements of petal length.
#
# Plot a histogram of the petal lengths of his 50 samples of Iris versicolor using **matplotlib/seaborn's** default settings. Recall that to specify the default seaborn style, you can use `sns.set()`, where `sns` is the alias that `seaborn` is imported as.
#
# The subset of the data set containing the *Iris versicolor *petal lengths in units of centimeters (cm) is stored in the NumPy array `versicolor_petal_length`.
#
#
# Plotting the histograms by using the __pandas library__ and indexing the __DataFrame__ to extract the desired column. Here, however, we only need to use the provided __NumPy array__.
#
#
# $\color{red}{\textbf{NOTE:}}$
#
# >Assigning plotting statements (except for `plt.show()`) to the __dummy variable__ `_`. __This is done to prevent unnecessary output from being displayed. It is not required for our solutions to these exercises, however it is good practice to use it.__
#
# __Alternatively__, if you are working in an interactive environment such as a __Jupyter notebook__, you could use a `;` after our plotting statements __to achieve the same effect__.

# %%
# Import necessary modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# loading the data into the pandas dataframe
iris = pd.read_csv('iris.csv')
iris.head()
# Out:
#    sepal length (cm)  sepal width (cm)  ...  petal width (cm)  species
# 0                5.1               3.5  ...               0.2   setosa
# 1                4.9               3.0  ...               0.2   setosa
# 2                4.7               3.2  ...               0.2   setosa
# 3                4.6               3.1  ...               0.2   setosa
# 4                5.0               3.6  ...               0.2   setosa
#
# [5 rows x 5 columns]

# %%
iris.isna().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# species              0
# dtype: int64

# %%
print(iris.columns )
print(iris.species.value_counts())
print(iris.shape)
print(iris.species.value_counts().sum())
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'species'],
#       dtype='object')
# versicolor    50
# virginica     50
# setosa        50
# Name: species, dtype: int64
# (150, 5)
# 150

# %%
iris.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# count         150.000000        150.000000         150.000000        150.000000
# mean            5.843333          3.054000           3.758667          1.198667
# std             0.828066          0.433594           1.764420          0.763161
# min             4.300000          2.000000           1.000000          0.100000
# 25%             5.100000          2.800000           1.600000          0.300000
# 50%             5.800000          3.000000           4.350000          1.300000
# 75%             6.400000          3.300000           5.100000          1.800000
# max             7.900000          4.400000           6.900000          2.500000

# %% [markdown]
# ```python
# versicolor_petal_length = df[df['species'] == 'Versicolor']['petal length (cm)']
# setosa_petal_length = df[df['species'] == 'Setosa']['petal length (cm)']
# virginica_petal_length = df[df['species'] == 'Virginica']['petal length (cm)']
#
# ```

# %%
# Display records only with species
versicolor = iris.loc[iris["species"] == "versicolor"]
virginica = iris.loc[iris["species"] == "virginica"]
setosa = iris.loc[iris["species"] == "setosa"]

print(versicolor.head())
print(virginica.head())
print(setosa.head())
# Out:
#     sepal length (cm)  sepal width (cm)  ...  petal width (cm)     species
# 50                7.0               3.2  ...               1.4  versicolor
# 51                6.4               3.2  ...               1.5  versicolor
# 52                6.9               3.1  ...               1.5  versicolor
# 53                5.5               2.3  ...               1.3  versicolor
# 54                6.5               2.8  ...               1.5  versicolor
#
# [5 rows x 5 columns]
#      sepal length (cm)  sepal width (cm)  ...  petal width (cm)    species
# 100                6.3               3.3  ...               2.5  virginica
# 101                5.8               2.7  ...               1.9  virginica
# 102                7.1               3.0  ...               2.1  virginica
# 103                6.3               2.9  ...               1.8  virginica
# 104                6.5               3.0  ...               2.2  virginica
#
# [5 rows x 5 columns]
# ...

# %%
print(versicolor['petal length (cm)'].shape)
print(versicolor['petal length (cm)'].sum())
print(versicolor['petal length (cm)'].value_counts())
print(versicolor['petal length (cm)'].describe())
print(np.mean(versicolor['petal length (cm)']))
print(np.median(versicolor['petal length (cm)']))
# Out:
# (50,)
# 212.99999999999997
# 4.5    7
# 4.7    5
# 4.0    5
# 4.2    4
# 4.4    4
# 3.9    3
# 4.1    3
# 4.6    3
# 4.8    2
# 4.3    2
# 4.9    2
# 3.5    2
# 3.3    2
# 5.1    1
# 3.8    1
# 3.7    1
# 3.6    1
# 3.0    1
# 5.0    1
# Name: petal length (cm), dtype: int64
# count    50.000000
# mean      4.260000
# std       0.469911
# min       3.000000
# 25%       4.000000
# 50%       4.350000
# 75%       4.600000
# max       5.100000
# Name: petal length (cm), dtype: float64
# 4.26
# 4.35

# %%
# Calculating sum, mean and mode of a particular column
sum_data = iris['sepal length (cm)'].sum() 
mean_data = iris['sepal length (cm)'].mean() 
median_data = iris['sepal length (cm)'].median() 
  
print("Sum:",sum_data, "\nMean:", mean_data, "\nMedian:",median_data)
# Out:
# Sum: 876.5
# Mean: 5.843333333333335
# Median: 5.8

# %%
# Set default Seaborn style
sns.set()

# display records for versicolor petal length
versicolor_petal_length = versicolor['petal length (cm)']

# Plot histogram of versicolor petal lengths
versicolor_petal_length.plot(kind='hist')

# Label axes & Show histogram
plt.xlabel('petal length (cm)')
plt.ylabel('count')
plt.show()

# %%
# using the dummy varible
# Set default Seaborn style
sns.set()

# Plot histogram of versicolor petal lengths
_ = plt.hist(versicolor_petal_length)

# Label axes & Show histogram
plt.xlabel('petal length (cm)')
plt.ylabel('count')
plt.show()

# %% [markdown]
# ### **Adjusting** the number of **bins** in a histogram
#
# The histogram above has made had 10 `bins`. This is the default of matplotlib.
#
# >The `"square root rule"` is a **commonly-used rule of thumb for choosing number of bins**: choose the number of bins to be the square root of the number of samples. Plot the histogram of **Iris versicolor petal** lengths again, this time using the square root rule for the number of bins. You specify the number of `bins` using the bins keyword argument of `plt.hist()`.
#
# The plotting utilities are already imported and the seaborn defaults already set. The variable you defined in the last exercise, `versicolor_petal_length`, is already in your namespace.

# %%
# Import numpy
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# versicolor_petal_length to numpy array
versicolor_petal_length = np.array(versicolor_petal_length)
print('type of data {}'.format(type(versicolor_petal_length)))

# Compute number of data points: n_data
n_data = len(versicolor_petal_length)

# Number of bins is the square root of number of data points: n_bins
n_bins = np.sqrt(n_data)

# Convert number of bins to integer: n_bins
n_bins = int(n_bins)

# Plot the histogram
_ = plt.hist(versicolor_petal_length, bins=n_bins)

# Label axes
_ = plt.xlabel('petal length (cm)')
_ = plt.ylabel('count')

# Show histogram
plt.show()
# Out:
# type of data <class 'numpy.ndarray'>

# %%
import pylab

# data.hist calls data.plot
# pandas.DataFrame.plot() returns a matplotlib axis
iris.hist(
    column=['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
       'petal width (cm)', 'species'],figsize=(12, 10)
    #,sharey=True, sharex=True
    )
pylab.suptitle("Analyzing distribution for the series", fontsize="xx-large")
# Out:
# Text(0.5, 0.98, 'Analyzing distribution for the series')

# %% [markdown]
# ### Creating **bee swarm plot** with Seaborn's

# %%
plt.figure(figsize=(12, 7))

# Create bee swarm plot with Seaborn's default settings
sns.swarmplot(x='species', y='petal length (cm)', data=iris)

# Label the axes
plt.xlabel('species')
plt.ylabel('petal length (cm)')

# Show the plot
plt.show()

# %% [markdown]
# __Interpreting a bee swarm plot__
#
# What conclusions could we draw from the above bee swarm plot of iris petal lengths?
#
# >**virginica petals** tend to be the **longest**, and **setosa petals** tend to be the **shortest** of the three species.

# %% [markdown]
# ### Computing the **ECDF**
#
# __ECDFs are among the most important plots in statistical analysis.__
#
# - Define a function with the signature `ecdf(data)`. Within the function definition,
#     - Compute the number of data points, `n`, using the `len()` function.
#
#     - The `x-values` are the sorted data. Use the `np.sort()` function to perform the sorting.
#
#     - The  data of the ECDF go from `1/n` to `1` in equally spaced increments. You can construct this using `np.arange()`. Remember, however, that the end value in `np.arange()` is not inclusive. Therefore, `np.arange()` will need to go from `1` to `n+1`. Be sure to divide this by `n`.
#
#     - The function returns the values `x` and `y`.

# %%
import numpy as np

def ecdf(data):
    """Compute ECDF for a one-dimensional array of measurements."""

    # Number of data points: n
    n = len(data)

    # x-data for the ECDF: x
    x = np.sort(data)

    # y-data for the ECDF: y
    y = np.arange(1, n+1) / n

    return x, y

# %% [markdown]
# ### Plotting the **ECDF** for Iris dataset

# %%
import numpy as np
import matplotlib.pyplot as plt

versicolor_pl = versicolor['petal length (cm)']
print('type of data {}'.format(type(versicolor_pl)))
versicolor_petal_length = np.array(versicolor_pl)
print('type of data {}'.format(type(versicolor_petal_length)))

def ecdf(data):
    """Compute ECDF for a one-dimensional array of measurements."""

    # Number of data points: n
    n = len(data)

    # x-data for the ECDF: x
    x = np.sort(data)

    # y-data for the ECDF: y
    y = np.arange(1, n+1) / n

    return x, y

# Compute ECDF for versicolor data: x_vers, y_vers
x_vers, y_vers = ecdf(versicolor_petal_length)

plt.figure(figsize=(12, 7))

# Generate plot
_ = plt.plot(x_vers, y_vers, marker = '.', linestyle = 'none')

# Make the margins nice
plt.margins(0.02)

# Label the axes
_ = plt.xlabel('length')
_ = plt.ylabel('ECDF')

# Display the plot
plt.show()
# Out:
# type of data <class 'pandas.core.series.Series'>
# type of data <class 'numpy.ndarray'>

# %% [markdown]
# ### Comparison of **ECDFs**
#
# ECDFs also allow us to compare two or more distributions (though plots get cluttered if we have too many).
#
# Here, we will plot ECDFs for the petal lengths of all three iris species. we have already wrote a function to generate ECDFs so we can put it to good use!
#
# To overlay all three ECDFs on the same plot, we can use `plt.plot()` three times, once for each ECDF. Remember to include `marker='.'` and `linestyle='none'` as arguments inside `plt.plot()`.

# %%
import numpy as np
import matplotlib.pyplot as plt

# display records for versicolor petal length(Pandas Series)
setosa_pl = setosa['petal length (cm)']
versicolor_pl = versicolor['petal length (cm)']
virginica_pl = virginica['petal length (cm)']

# Changing the data from pandas.series to numpy array 
setosa_petal_length = np.array(setosa_pl)
versicolor_petal_length = np.array(versicolor_pl)
virginica_petal_length = np.array(virginica_pl)

# ECDF function
def ecdf(data):
    """Compute ECDF for a one-dimensional array of measurements."""

    # Number of data points: n
    n = len(data)

    # x-data for the ECDF: x
    x = np.sort(data)

    # y-data for the ECDF: y
    y = np.arange(1, n+1) / n

    return x, y

# Compute ECDFs
x_set, y_set = ecdf(setosa_petal_length)
x_vers, y_vers = ecdf(versicolor_petal_length)
x_virg, y_virg = ecdf(virginica_petal_length)

plt.figure(figsize=(12, 7))

# Plot all ECDFs on the same plot
_ = plt.plot(x_set, y_set, marker = 'o', linestyle = 'none')
_ = plt.plot(x_vers, y_vers, marker = 'o', linestyle = 'none')
_ = plt.plot(x_virg, y_virg, marker = 'o', linestyle = 'none')

# Make nice margins
plt.margins(0.02)

# Annotate the plot
plt.legend(('setosa', 'versicolor', 'virginica'), loc='lower right')
_ = plt.xlabel('petal length (cm)')
_ = plt.ylabel('ECDF')

# Display the plot
plt.show()

# %% [markdown]
# The **ECDFs** expose clear differences among the species. Setosa is much shorter, also with less absolute variability in petal length than versicolor and virginica

# %% [markdown]
# ## __2 Summary Statistics: The sample Mean and Median__

# %% [markdown]
# ### Computing **mean** & **median**
#
# The mean of all measurements gives an indication of the typical magnitude of a measurement. It is computed using `np.mean()`.

# %%
print(iris.columns )
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'species'],
#       dtype='object')

# %%
# Compute the mean: mean_length_vers
mean_length_vers = np.mean(versicolor_petal_length)
median__vers = np.median(versicolor_petal_length)

# Print the result with some nice formatting
print('versicolor mean petal length = {} cm'.format(mean_length_vers))
print('versicolor median petal length = {} cm'.format(median__vers))
# Out:
# versicolor mean petal length = 4.26 cm
# versicolor median petal length = 4.35 cm

# %% [markdown]
# ### Computing **percentiles**

# %%
# Specify array of percentiles: percentiles
percentiles = np.array([2.5, 25, 50, 75, 97.5])

# Compute percentiles: ptiles_vers
ptiles_vers = np.percentile(versicolor_petal_length, percentiles)

# Print the result
print(ptiles_vers)
# Out:
# [3.3    4.     4.35   4.6    4.9775]

# %% [markdown]
# ### Comparing **percentiles** to **ECDF**

# %%
# importing modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Display records only with species
versicolor = iris.loc[iris["species"] == "versicolor"]
versicolor_pl = versicolor['petal length (cm)']   # pandas.core.series.Series
versicolor_petal_length = np.array(versicolor_pl) # Converting it to numpy.ndarray

# Computing the ECDF
def ecdf(data):
    """Compute ECDF for a one-dimensional array of measurements."""

    # Number of data points: n
    n = len(data)

    # x-data for the ECDF: x
    x = np.sort(data)

    # y-data for the ECDF: y
    y = np.arange(1, n+1) / n

    return x, y

# Compute ECDF for versicolor data: x_vers, y_vers
x_vers, y_vers = ecdf(versicolor_petal_length)

# Set default Seaborn style
sns.set()

# figure size
plt.figure(figsize=(12, 7))

# Generate plot
_ = plt.plot(x_vers, y_vers,
             marker = 'o', color='tab:blue',
             linestyle = 'none', alpha=0.5, 
             label='ECDF')

# Overlay percentiles as red diamonds.
_ = plt.plot(ptiles_vers, 
             percentiles / 100, 
             marker='D', color='tab:red',
             linestyle='none', label='percentiles point')

# Make the margins nice
plt.margins(0.02)

# Label the axes
_ = plt.xlabel('length')
_ = plt.ylabel('ECDF')
_ = plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# ### **Box** and **whisker plot**
# **bold text**
# Making a box plot for the petal lengths is unnecessary because the iris data set is not too large and the bee swarm plot works fine. However, it is always good to get some practice. Make a box plot of the iris petal lengths. You have a pandas DataFrame, df, which contains the petal length data, in your namespace. Inspect the data frame df in the IPython shell using ```df.head()``` to make sure you know what the pertinent columns are.
#
# For your reference, the code used to produce the box plot in the video is provided below:
# ```python
# _ = sns.boxplot(x='east_west', y='dem_share', data=df_all_states)
# _ = plt.xlabel('region')
# _ = plt.ylabel('percent of vote for Obama')
# ```
# In the IPython Shell, you can use ```sns.boxplot?``` or ```help(sns.boxplot)``` for more details on how to make box plots using seaborn.

# %%
# Figure size
plt.figure(figsize=(12, 10))

# Create box plot with Seaborn`s default settings
_ = sns.boxplot(x='species', y='petal length (cm)', data=iris)

# Label the axes
_ = plt.xlabel('species')
_ = plt.ylabel('petal length (cm)')

# %%
# Combined Box and swarmplot
# Figure size
plt.figure(figsize=(12, 10))

# Create bee swarm plot with Seaborn's default settings
_ = sns.boxplot(x='species', y='petal length (cm)', data=iris, whis=np.inf) 
_ = sns.swarmplot(x='species', y='petal length (cm)', data=iris, color=".2")

# Label the axes
_ = plt.xlabel('species')
_ = plt.ylabel('petal length (cm)')

# Show the plot
plt.show()

# %% [markdown]
# ### **Variance** and **standard deviation**
#
# <p align='center'>
#     <a href='#'><img src='https://github.com/mohd-faizy/CAREER-TRACK-Data-Scientist-with-Python/blob/main/22_Statistical-Thinking-in-Python-%5BPart%20-1%5D/_png/SDvsVar.png?raw=true'></a>
# </p>

# %% [markdown]
# ### Computing the **variance**

# %% [markdown]
# >__Variance__ is the mean **squared distance** of the data from their **mean**. Informally, a measure of the ***spread of data***.
#
# $$ variance = \dfrac{1}{n}\sum^{n}_{i=1}(x_i - \bar{x})^2 $$

# %%
# Array of differences to mean: differences
differences = np.array(versicolor_petal_length - np.mean(versicolor_petal_length))

# Square the differences: diff_sq
diff_sq = differences ** 2

# Compute the mean square difference: variance_explicit
variance_explicit = np.mean(diff_sq)

# Compute the variance using NumPy: variance_np
variance_np = np.var(versicolor_petal_length)

# Print the results
print('Variance Explict {0:.4f}'.format(variance_explicit))
print('Variance Numpy {0:.4f}'.format(variance_np))
# Out:
# Variance Explict 0.2164
# Variance Numpy 0.2164

# %% [markdown]
# ### The **standard deviation** and the **variance**

# %% [markdown]
# >__Standard Deviation__  is a measure that is used to **quantify** the amount of ***variation*** or ***dispersion*** of a set of data values.
#
# $$ Standard Deviation = \sqrt{\dfrac{\sum(x_i - \bar{x})^2}{n - 1}} $$

# %%
# Compute the variance: variance
variance = np.var(versicolor_petal_length)

# Print the square root of the variance
print('Variance {0:.4f}'.format(np.sqrt(variance)))

# Print the standard deviation
print('Standard Deviation {0:.4f}'.format(np.std(versicolor_petal_length)))
# Out:
# Variance 0.4652
# Standard Deviation 0.4652

# %% [markdown]
# ### **Covariance** and the **Pearson correlation coefficient**

# %%
versicolor = iris.loc[iris["species"] == "versicolor"]
versicolor_petal_length = versicolor['petal length (cm)']
versicolor_petal_width = versicolor['petal width (cm)']

print('versicolor petal length mean {0:.2f}'.format(versicolor_petal_length.mean()))
print('versicolor petal width mean {0:.2f}'.format(versicolor_petal_width.mean()))

# Set default Seaborn style
sns.set()

# figure size
plt.figure(figsize=(12, 7))

# vertical mean line 
plt.axvline(versicolor_petal_length.mean(), color='red',
            linestyle='dashed', linewidth=1,
            label='versicolor petal length mean')

# horizontal mean line
plt.axhline(versicolor_petal_width.mean(), color='k',
            linestyle='dashed', linewidth=1,
            label='versicolor petal width mean')

# Make a scatter plot
_ = plt.plot(versicolor_petal_length, versicolor_petal_width,
             marker='o', linestyle='none')

# Set margins
_ = plt.margins(0.02)

# Label the axes
_ = plt.xlabel('versicolor petal length')
_ = plt.ylabel('versicolor petal width')
_ = plt.title('plot how I.versicolor petal length and width are related')
_ = plt.legend()

# Show the result
plt.show()
# Out:
# versicolor petal length mean 4.26
# versicolor petal width mean 1.33

# %% [markdown]
# #### __Covariance__
#
# it is the measure of how the two quantities vary together.
#
# - Covariance is a measure of the relationship between two random variables and to what extent, they change together. Or we can say, in other words, it defines the changes between the two variables, such that change in one variable is equal to change in another variable.
#
# - If the covariance for any two variables is positive, that means, both the variables move in the same direction. Here, the variables show similar behaviour.
#
# $$ covariance = \dfrac{1}{n}\sum^{n}_{i=1}(x_i - \bar{x})(y_i - \bar{y})$$

# %% [markdown]
# ### Variance and covariance by looking
#
# Consider four scatter plots of $x-y$ data, appearing to the right. Which has, respectively,
#
# - the highest variance in the variable $x$,
# - the highest covariance,
# - negative covariance?
#
#
#
# <p align='center'>
#     <a href='#'><img src='https://github.com/mohd-faizy/CAREER-TRACK-Data-Scientist-with-Python/blob/main/22_Statistical-Thinking-in-Python-%5BPart%20-1%5D/_png/var_cov.png?raw=true' width=500 height=400></a>
# </p>
#
# $\color{red}{\textbf{Answer:}}$ __(d, c, b)__

# %% [markdown]
# #### Computing the covariance
#
# The covariance may be computed using the Numpy function `np.cov()`. For example, we have two sets of data `x` and `y`, `np.cov(x, y)` returns a `2D` array where entries `[0,1]` and `[1,0]` are the covariances.
#
# Entry `[0,0]` is the **variance** of the data in x, and entry `[1,1]` is the variance of the data in y.
#
# This `2D` output array is called the __covariance matrix__, since it organizes the self- and covariance.

# %%
versicolor = iris.loc[iris["species"] == "versicolor"]
versicolor_petal_length = versicolor['petal length (cm)']
versicolor_petal_width = versicolor['petal width (cm)']

# Compute the covariance matrix: covariance_matrix
covariance_matrix = np.cov(versicolor_petal_length, versicolor_petal_width)

# Print covariance matrix
print(covariance_matrix)

# Extract covariance of length and width of petals: petal_cov
petal_cov = covariance_matrix[0, 1]

# Print the length/width covariance
print(petal_cov)
# Out:
# [[0.22081633 0.07310204]
#  [0.07310204 0.03910612]]
# 0.07310204081632653

# %%
# 3D scatter plot 
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(12, 7))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(iris['petal width (cm)'], 
           iris['petal length (cm)'], 
           iris['sepal length (cm)'],
           color='tab:red')


ax.set_xlabel('PetalWidthCm')
ax.set_ylabel('PetalLengthCm')
ax.set_zlabel('SepalLengthCm')

plt.tight_layout(pad=0.5)
plt.show()

# %% [markdown]
# #### __Pearson correlation coefficient__
#
#
# We can compute the **covariance** using built-in NumPy functions. However, if we want to have a more **generally applicable measure** of **how two variables depend on each other**, we want it to be **dimensionless**, that is to not have any units.
#
# So, we can divide the covariance by the ***standard deviations of the x and y variables***. This is called the Pearson correlation coefficient, usually denoted by the Greek letter rho.

# %% [markdown]
# #### ___Why is the Pearson correlation coefficient important?___
#
# It helps in knowing **how strong the relationship between the two variables** is. Not only the presence or the absence of the correlation between the two variables is indicated using the Pearson Correlation Coefficient but it also determines the **exact extent to which those variables are correlated**.
#
#
# The **Pearson coefficient correlation** has a **high statistical significance**. It looks at the relationship between two variables. It seeks to draw a line through the data of two variables to show their relationship. The relationship of the variables is measured with the help Pearson correlation coefficient calculator.

# %% [markdown]
# $$ \begin{align} \rho &= \text{Pearson correlation} = \dfrac{\text{covariance}}{(\text{std of x})(\text{std of y})} \\ &= \dfrac{\text{variability due to codependence}}{\text{independent variability}} \end{align}$$

# %% [markdown]
# __Pandas__
#
# Example
# ```python
# >>> x.corr(y)                     # Pearson's r
# 0.7586402890911867
# >>> y.corr(x)
# 0.7586402890911869
# >>> x.corr(y, method='spearman')  # Spearman's rho
# 0.9757575757575757
# >>> x.corr(y, method='kendall')   # Kendall's tau
# ```

# %% [markdown]
# __Scipy__
#
# Example
# ```python
# >>> import numpy as np
# >>> import scipy.stats
# >>> x = np.arange(10, 20)
# >>> y = np.array([2, 1, 4, 5, 8, 12, 18, 25, 96, 48])
# >>> scipy.stats.pearsonr(x, y)    # Pearson's r
# (0.7586402890911869, 0.010964341301680832)
# >>> scipy.stats.spearmanr(x, y)   # Spearman's rho
# SpearmanrResult(correlation=0.9757575757575757, pvalue=1.4675461874042197e-06)
# >>> scipy.stats.kendalltau(x, y)  # Kendall's tau
# KendalltauResult(correlation=0.911111111111111, pvalue=2.9761904761904762e-05)
#
# ```

# %% [markdown]
# |Pearson’s r Value|Correlation Between x and y|
# |-----------------|---------------------------|
# |equal to 1|perfect positive linear relationship|
# |greater than 0|positive correlation|
# |equal to 0|independent|
# |less than 0|negative correlation|
# |equal to -1|perfect negative linear relationship|
#
# >In short, a **larger absolute value of r** indicates **stronger correlation**, closer to a linear function. A **smaller absolute value of r** indicates weaker correlation.

# %% [markdown]
# #### __Computing the Pearson correlation coefficient__
#
# The **Pearson correlation coefficient**, also called the ***Pearson r***, is often **easier to interpret** than **Covariance**.
#
# It is computed using the `np.corrcoef()` function. Like `np.cov()`, it **takes two arrays** as arguments and returns a 2D array. Entries `[0,0]` and `[1,1]` are necessarily equal to `1` (**think why?**), and the value we are after is entry `[0,1]`.
#
# In this exercise, we will write a function, `pearson_r(x, y)` that takes in **two arrays** and **returns the Pearson correlation coefficient**. You will then use this function to compute it for the petal lengths and widths of I. versicolor.
#
# Again, we include the scatter plot you generated in a previous exercise to remind you how the petal width and length are related.

# %% [markdown]
# __Instructions__
#
# - Define a function with signature `pearson_r(x, y)`.
#
#     - Use `np.corrcoef()` to compute the correlation matrix of x and y (pass them to np.corrcoef() in that order).
#
#     - The function returns entry `[0,1]` of the correlation matrix.
#
# - Compute the Pearson correlation between the data in the arrays `versicolor_petal_length` and `versicolor_petal_width`. Assign the result to r.
#
# - Print the result.

# %%
def pearson_r(x, y):
    """Compute Pearson correlation coefficient between two arrays
    
    Args:
        x: arrays
        y: arrays
        
    returns:
        r: int
    """
    # Compute correlation matrix: corr_mat
    corr_mat = np.corrcoef(x, y)
    
    # Return entry[0, 1]
    return corr_mat[0, 1]

# Compute Pearson correlation coefficient for I. versicolor: r
r = pearson_r(versicolor_petal_length, versicolor_petal_width)

# Print the result
print(r)
# Out:
# 0.7866680885228169

# %% [markdown]
# <p align='center'>
#     <a href="https://twitter.com/F4izy">
#         <img src="https://th.bing.com/th/id/OIP.FCKMemzqNplY37Jwi0Yk3AHaGl?w=233&h=207&c=7&o=5&pid=1.7" width=50px
#             height=50px>
#     </a>
#     <a href="https://www.linkedin.com/in/mohd-faizy/">
#         <img src='https://th.bing.com/th/id/OIP.idrBN-LfvMIZl370Vb65SgHaHa?pid=Api&rs=1' width=50px height=50px>
#     </a>
# </p>
