# %% [markdown]
# # <center>**Intermediate Data Visualization with Seaborn📊📈📉**</center>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
url_FY18 = 'https://raw.githubusercontent.com/mohd-faizy/CAREER-TRACK-Data-Scientist-with-Python/main/10_Intermediate%20Data%20Visualization%20with%20Seaborn/_datasets/FY18_4050_FMRs.csv'
url_bike_share = 'https://raw.githubusercontent.com/mohd-faizy/CAREER-TRACK-Data-Scientist-with-Python/main/10_Intermediate%20Data%20Visualization%20with%20Seaborn/_datasets/bike_share.csv'
url_college_data = 'https://raw.githubusercontent.com/mohd-faizy/CAREER-TRACK-Data-Scientist-with-Python/main/10_Intermediate%20Data%20Visualization%20with%20Seaborn/_datasets/college_datav3.csv'
url_daily_show = 'https://raw.githubusercontent.com/mohd-faizy/CAREER-TRACK-Data-Scientist-with-Python/main/10_Intermediate%20Data%20Visualization%20with%20Seaborn/_datasets/daily_show_guests_cleaned.csv'
url_insurance = 'https://raw.githubusercontent.com/mohd-faizy/CAREER-TRACK-Data-Scientist-with-Python/main/10_Intermediate%20Data%20Visualization%20with%20Seaborn/_datasets/insurance_premiums.csv'
url_school_grants = 'https://raw.githubusercontent.com/mohd-faizy/CAREER-TRACK-Data-Scientist-with-Python/main/10_Intermediate%20Data%20Visualization%20with%20Seaborn/_datasets/schoolimprovement2010grants.csv'

# %%
fy18 = pd.read_csv(url_FY18)
bike_share = pd.read_csv(url_bike_share)
college_data = pd.read_csv(url_college_data)
daily_show = pd.read_csv(url_daily_show)
insurance = pd.read_csv(url_insurance)
school_grants = pd.read_csv(url_school_grants)

# %%
data_url = [url_FY18 , url_bike_share, url_college_data, url_daily_show, url_insurance, url_school_grants]
data_name = ['FY18', 'bike_share', 'college_data', 'daily_show', 'insurance', 'school_grants']

for name, url in zip(data_name, data_url):
    df = pd.read_csv(url)
    print(name)
    print('-'*100)
    display(df.columns)
    print('\n')
# Out:
# FY18
# ----------------------------------------------------------------------------------------------------
# Index(['fips2010', 'fmr_0', 'fmr_1', 'fmr_2', 'fmr_3', 'fmr_4', 'state',
#        'metro_code', 'areaname', 'county', 'cousub', 'countyname',
#        'county_town_name', 'pop2010', 'acs_2017_2', 'state_alpha', 'fmr_type',
#        'metro', 'fmr_pct_chg', 'fmr_dollar_chg'],
#       dtype='object')
# bike_share
# ----------------------------------------------------------------------------------------------------
# Index(['dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday', 'workingday',
#        'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'casual',
#        'registered', 'total_rentals'],
#       dtype='object')
# college_data
# ----------------------------------------------------------------------------------------------------
# Index(['INSTNM', 'OPEID', 'REGION', 'SAT_AVG_ALL', 'PCTPELL', 'PCTFLOAN',
# ...

# %% [markdown]
# # 1️⃣**Seaborn Introduction**

# %% [markdown]
# #### **Introduction to Seaborn**

# %%
school_grants['Award_Amount'].plot.hist()
plt.show()

# %% [markdown]
# #### **Comparing the histogram and displot**

# %%
# Display a Seaborn distplot(deprecated function)
sns.displot(school_grants['Award_Amount'])
plt.show()

# %%
sns.displot(school_grants['Award_Amount'], kde=True)
plt.show()

# %% [markdown]
# ## **Using the distribution plot**

# %% [markdown]
# #### **Plot a histogram**

# %%
# Create a histplot
sns.displot(school_grants['Award_Amount'],
            kde=False,
            bins=20)
plt.show()

# %% [markdown]
# #### **Rug plot and kde shading**

# %%
# Create a displot of the Award Amount
sns.displot(school_grants['Award_Amount'],
             kind='kde',
             rug=True,
             fill=True)

# Plot the results
plt.show()

# %%
sns.kdeplot(data=school_grants['Award_Amount'], fill=True)
sns.rugplot(data=school_grants['Award_Amount'])
plt.show()

# %% [markdown]
# `75` of the `757` awards are `<= $400k`. This insight could be useful for further analysis.

# %% [markdown]
# ## **Regression Plot In Seaborn**

# %% [markdown]
# | Feature        | lmplot                                      | regplot                                      |
# |----------------|---------------------------------------------|----------------------------------------------|
# | Function       | FacetGrid with regression plots              | Scatter plot with regression line             |
# | Usage          | Explore relationships across multiple plots | Examine relationship between two variables    |
# | Data           | Can handle wide-form and long-form datasets | Requires a single DataFrame                  |
# | Plot Type      | Supports various plot types (e.g., scatter, line, etc.) | Mainly used for scatter plots with regression line |
# | Multiple Plots | Automatically creates subplots               | Requires explicit subplot creation            |
# | Categorical    | Handles categorical variables (hue, col, row) | Limited support for categorical variables     |
# | Flexibility    | Offers extensive customization options       | Limited customization options                |
# | Regression Fit | Provides confidence intervals and bootstrapped estimates | Provides confidence intervals only            |
# | Integration    | Integrated with other Seaborn functions      | Standalone function                          |

# %% [markdown]
# #### **Create a regression plot**

# %%
sns.regplot(x='insurance_losses', y='premiums', data=insurance)
plt.show()

# %%
sns.lmplot(x='insurance_losses', y='premiums', data=insurance, height=5, aspect=2)
plt.show()

# %% [markdown]
# #### **Plotting multiple variables**

# %%
# Create a regression plot using hue
sns.lmplot(data=insurance,
           x="insurance_losses",
           y="premiums",
           hue="Region",
           height=5, aspect=2)

plt.show()

# %% [markdown]
# #### **Facetting multiple regressions**

# %%
# Create a regression plot with multiple rows
sns.lmplot(data=insurance,
           x="insurance_losses",
           y="premiums",
           hue="Region",
           row="Region",
           height=5,
           aspect=2)

plt.show()

# %% [markdown]
# `displot` `distplot` **(deprecated)**, `histplot`, `kdeplot`, `rugplot`, `regplot`, `lmplot`

# %% [markdown]
# # 2️⃣**Customizing Seaborn Plots**

# %% [markdown]
# ## **Using Seaborn Styles**

# %% [markdown]
# #### **Setting the default style**

# %%
# Plot the pandas histogram
plt.figure(figsize=(10, 5))
fy18['fmr_2'].plot.hist()
plt.show()

# %%
# Set the default seaborn style: darkgrid
sns.set()
plt.figure(figsize=(10, 5))

# Plot the pandas histogram again
fy18['fmr_2'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# #### **Comparing styles**

# %%
sns.set_style('dark')
plt.figure(figsize=(10, 5))
sns.histplot(fy18['fmr_2'], kde=True)
plt.show()

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10, 5))
sns.histplot(fy18['fmr_2'], kde=True)
plt.show()

# %% [markdown]
# #### **Removing spines**
#
# In general, visualizations should minimize extraneous markings so that the data speaks for itself. Seaborn allows you to remove the lines on the top, bottom, left and right axis, which are often called spines.

# %%
# Ste the style to white
sns.set_style('white')
plt.figure(figsize=(10, 5))

# Create a regression plot
sns.lmplot(data=fy18,
          x='pop2010',
          y='fmr_2',
          height=5,
          aspect=2)

# Remove the spines
# Spines are the lines that border the plot area. By default, they are present on the top and right sides of the plot.
sns.despine(right=True, top=True)
plt.show()

# %% [markdown]
# ## **Colors in Seaborn**
# #### **Matplotlib color codes**

# %%
# Set styles, enable color code, and create a magenta distplot
sns.set(color_codes=True)
plt.figure(figsize=(10, 5))
sns.displot(fy18['fmr_3'], kde=True, color='m')
plt.show()

# %% [markdown]
# #### **Using default palettes**

# %%
# Loop through differences between bright and colorblind palettes
for p in ['bright', 'colorblind']:
    sns.set_palette(p)
    plt.figure(figsize=(10, 5))
    sns.displot(fy18['fmr_3'], kde=True)
    plt.show()

# %% [markdown]
# #### **Creating Custom Palettes**

# %%
sns.palplot(sns.color_palette('Purples', 8))
plt.show()

# %%
sns.palplot(sns.color_palette('husl', 10))
plt.show()

# %%
sns.palplot(sns.color_palette('coolwarm', 6))
plt.show()

# %% [markdown]
# ## **Customizing with matplotlib**
# #### **Using matplotlib axes**

# %%
sns.set_palette('tab20')

# Create a figure and axes
fig, ax = plt.subplots(figsize=(10, 5))

# Plot the distribution of data
sns.histplot(fy18['fmr_3'], ax=ax, kde=True)

# Create a more descriptive x axis label
ax.set(xlabel="3 Bedroom Fair Market Rent",
       ylabel="Number of count")

plt.show()

# %% [markdown]
# #### **Additional plot customizations**

# %%
# Create a figure and axes
fig, ax = plt.subplots(figsize=(10, 5))

# Plot the distribution of 1 bedroom rents
sns.histplot(fy18['fmr_1'], ax=ax, kde=True)

# Modify the properties of the plot
ax.set(xlabel='1 Bedroom Fair Market Rent',
       xlim=(100, 1500),
       title='US Rent')

plt.show()

# %% [markdown]
# #### **Adding annotations**

# %%
# Create a figure and axes, Then plot the data
fig, ax = plt.subplots(figsize=(10, 5))
sns.histplot(fy18['fmr_1'], ax=ax, kde=True)

# Customize the labels and limits
ax.set(xlabel='1 Bedroom Fair Market Rent', 
       xlim=(100, 1500),
       title='US Rent')

# Add vertical lines for the median and mean
ax.axvline(x=fy18['fmr_1'].median(),
           color='r',
           label='Median',
           linestyle='--',
           linewidth=2)

ax.axvline(x=fy18['fmr_1'].mean(),
           color='g',
           label='Mean',
           linestyle='-',
           linewidth=2)

# Show the legend
ax.legend()

plt.show()

# %% [markdown]
# #### **Multiple plots**

# %%
# Create a plot with 1 row and 2 columns that share the y axis label
fig, (ax0, ax1) = plt.subplots(nrows=1, ncols=2, sharey=True, figsize=(15, 5))

# Plot the distribution of 1 bedroom apartments on ax0
sns.histplot(fy18['fmr_1'], ax=ax0, kde=True)
ax0.set(xlabel='1 Bedroom Fair Market Rent', xlim=(100, 1500))

# Plot the distribution of 2 bedroom apartments on ax1
sns.histplot(fy18['fmr_2'], ax=ax1, kde=True)
ax1.set(xlabel='2 Bedroom Fair Market Rent', xlim=(100, 1500))

plt.show()

# %% [markdown]
# # 3️⃣**Additional Plot Types**

# %% [markdown]
# ## **Categorical Plot Types**

# %% [markdown]
# #### `stripplot()` and `swarmplot()`

# %%
sns.stripplot(data=school_grants,
             x='Award_Amount',
             y='Model Selected',
             jitter=True,
             hue='Model Selected')

plt.show()

# %%
plt.figure(figsize=(10, 7))

# Create and display a swarmplot with hue set to the Region
sns.swarmplot(data=school_grants,
             x='Award_Amount',
             y='Model Selected',
             hue='Region',
             palette='husl')

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 7.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 8.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# #### **`boxplots`, `violinplots` and `boxenplots`**

# %%
# Create a boxplot
sns.boxplot(data=school_grants,
           x='Award_Amount',
           y='Model Selected',
           palette='husl')

plt.show()

# %%
# Create a violinplot with the husl palette
sns.violinplot(data=school_grants,
              x='Award_Amount',
              y='Model Selected',
              palette='husl')
# Out:
# <Axes: xlabel='Award_Amount', ylabel='Model Selected'>

# %%
plt.figure(figsize=(10, 7))

# Create a lvplot(boxenplot) with the Paired palette and the Region column as the hue
sns.boxenplot(data=school_grants,
              x='Award_Amount',
              y='Model Selected',
              palette='Paired',
              hue='Region')

plt.show()

# %% [markdown]
# #### `barplots`, `pointplots` and `countplots`

# %%
plt.figure(figsize=(10, 7))

# Show a countplot with the number of models used with each region a different color
sns.countplot(data=school_grants,
             y='Model Selected',
             hue='Region')

plt.show()

# %%
plt.figure(figsize=(10, 7))

# Create a pointplot and include the capsize in order to show bars on the confidence interval
sns.pointplot(data=school_grants,
         y='Award_Amount',
         x='Model Selected',
         capsize=.1)

plt.show()

# %%
plt.figure(figsize=(10, 7))

# Create a barplot with each Region shown as a different color
sns.barplot(data=school_grants,
           y='Award_Amount',
           x='Model Selected',
           hue='Region')

plt.show()

# %% [markdown]
# ## **Regression Plots**

# %% [markdown]
# #### **Regression and residual plots**

# %%
# Display a regression plot for Tuition
sns.regplot(data=college_data,
           x='SAT_AVG_ALL',
           y='Tuition',
           marker='^',
           color='g')

plt.show()

# %%
# Display the residual plot
sns.residplot(data=college_data,
             x='SAT_AVG_ALL',
             y='Tuition',
             color='g')

plt.show()

# %% [markdown]
# #### **Regression plot parameters**

# %%
# Plot a regression plot of Tuition and the Percentage of Pell Grants
sns.regplot(data=college_data,
           y='Tuition',
           x='PCTPELL')

plt.show()

# %%
# Create another plot that estimates the tuition by PCTPELL
sns.regplot(data=college_data,
           x='PCTPELL',
           y='Tuition',
           x_bins=5)

plt.show()

# %%
# The final plot should include a line using a 2nd order polynomial
sns.regplot(data=college_data,
           y='Tuition',
           x='PCTPELL',
           x_bins=5,
           order=2)

plt.show()

# %% [markdown]
# #### **Binning data**

# %%
# Create a scatter plot by disabling the regression line
sns.regplot(data=college_data,
           y='Tuition',
           x='UG',
           fit_reg=False)
# Out:
# <Axes: xlabel='UG', ylabel='Tuition'>

# %%
# Create a scatter plot and bin the data into 5 bins
sns.regplot(data=college_data,
           y='Tuition',
           x='UG',
           x_bins=5)
# Out:
# <Axes: xlabel='UG', ylabel='Tuition'>

# %%
# Create a regplot and bin the data into 8 bins
sns.regplot(data=college_data,
           y='Tuition',
           x='UG',
           x_bins=8)
# Out:
# <Axes: xlabel='UG', ylabel='Tuition'>

# %% [markdown]
# ## **Matrix plots**

# %% [markdown]
# #### **Creating heatmaps**

# %%
# Create a crosstab table of the data
pd_crosstab = pd.crosstab(daily_show['Group'], daily_show['YEAR'])
display(pd_crosstab)

# Plot a heatmap of the table
sns.heatmap(pd_crosstab, linewidths=0.1)

# Rotate tick marks for visibility
plt.yticks(rotation=0)
plt.xticks(rotation=90)

plt.show()
# Out:
# YEAR            1999  2000  2001  2002  2003  2004  2005  2006  2007  2008  \
# Group
# Academic           0     0     2     0     4     1    12     9    13     5
# Acting           108   100    92    84    74    51    44    44    25    26
# Advocacy           0     1     0     1     0     4     0     0     2     3
# Athletics          0     3     1     2     0     2     2     5     4     1
# Business           0     1     0     0     0     2     1     1     2     1
# Clergy             0     0     0     1     1     1     0     0     1     0
# Comedy            25    12    11     5    12     7     5     8     9     7
# Consultant         0     0     0     0     1     4     1     4     2     3
# Government         0     0     2     1     2     3     1     3     1     0
# Media             11    21    31    42    41    45    54    47    47    77
# Military           0     0     0     0     0     0     1     1     3     1
# ...

# %% [markdown]
# #### **Customizing heatmaps**

# %%
# Create the crosstab DataFrame
pd_crosstab = pd.crosstab(daily_show['Group'], daily_show['YEAR'])

# Plot a heatmap of the table with no color bar and using the BuGn palette
sns.heatmap(pd_crosstab, cbar=False, cmap='BuGn', linewidths=0.3)

# Rotate tick marks for visibility
plt.yticks(rotation=0)
plt.xticks(rotation=90)

#Show the plot
plt.show()

# %% [markdown]
# # 4️⃣**Creating Plots on Data Aware Grids**

# %% [markdown]
# ## **Using `FacetGrid`, `catplot` and `lmplot`**

# %% [markdown]
# #### **Building a FacetGrid**

# %%
# Create FacetGrid with Degree_Type and specify the order of the rows usiung row_order
g2 = sns.FacetGrid(college_data, row='Degree_Type',
                  row_order=['Graduate', 'Bachelors', 'Associates', 'Certificate'])

# Map a pointplot of SAT_AVG_ALL onto the grid
g2.map(sns.pointplot, 'SAT_AVG_ALL', order=['Graduate', 'Bachelors', 'Associates', 'Certificate'])

plt.show()

# %% [markdown]
# #### **Using a catplot**

# %%
# Create a factorplot(catplot in latest seaborn) that contains boxplots of Tuition values
sns.catplot(data=college_data,
              x='Tuition',
              kind='box',
              row='Degree_Type')

plt.show()

# %%
# Create a facetted pointplot of Average SAT_AVG_ALLl scores facetted by Degree_Type
sns.catplot(data=college_data,
              x='SAT_AVG_ALL',
              kind='point',
              row='Degree_Type',
              row_order=['Graduate', 'Bachelors', 'Associates', 'Certificate'])

plt.show()

# %% [markdown]
# #### **Using a lmplot**

# %%
# Create a FacetGrid varying by column and columns ordered with the degree_order variable
degree_ord = ['Graduate', 'Bachelors', 'Associates']
g = sns.FacetGrid(college_data, col='Degree_Type', col_order=degree_ord)

# Map a scatterplot of Undergrad Population compared to PCTPELL
g.map(plt.scatter, 'UG', 'PCTPELL')

plt.show()

# %%
# Re-create the plot above as an lmplot
sns.lmplot(data=college_data,
          x='UG',
          y='PCTPELL',
          col='Degree_Type',
          col_order=degree_ord)

plt.show()

# %%
# Create an lmplot that has a column for Ownership, a row for Degree_Type and hue based on the WOMENONLY column
inst_ord = ['Public', 'Private non-profit']

sns.lmplot(data=college_data,
          x='SAT_AVG_ALL',
          y='Tuition',
          col='Ownership',
          row='Degree_Type',
          row_order=['Graduate', 'Bachelors'],
          hue='WOMENONLY',
          col_order=inst_ord)

plt.show()

# %% [markdown]
# ## **Using PairGrid and pairplot**

# %% [markdown]
# #### **Building a PairGrid**

# %%
# Create a PairGrid with a scatter plot for fatal_collisions and premiums
g = sns.PairGrid(insurance, vars=["fatal_collisions", "premiums"])
g2 = g.map(sns.scatterplot)

plt.show()

# %%
# Create the same PairGrid but map a histogram on the diag
g = sns.PairGrid(insurance, vars=["fatal_collisions", "premiums"])
g2 = g.map_diag(sns.histplot)
g3 = g2.map_offdiag(sns.scatterplot)

plt.show()

# %% [markdown]
# #### **Using a pairplot**

# %%
# Create a pairwise plot of the variables using a scatter plot
sns.pairplot(insurance,
            vars=['fatal_collisions', 'premiums'],
             kind='scatter'
            )

plt.show()

# %%
# Plot the same data but use a different color palette and color code by Region
sns.pairplot(insurance,
            vars=['fatal_collisions', 'premiums'],
            kind='scatter',
            hue='Region',
            palette='RdBu',
            diag_kws={'alpha':.5})

plt.show()

# %% [markdown]
# #### **Additional pairplots**

# %%
# Build a pairplot with different x and y variables
sns.pairplot(data=insurance,
            x_vars=['fatal_collisions_speeding', 'fatal_collisions_alc'],
            y_vars=['premiums', 'insurance_losses'],
            kind='scatter',
            hue='Region',
            palette='husl')

plt.show()

# %%
# plot relationships between insurance_losses and premiums
sns.pairplot(data=insurance,
            vars=['insurance_losses', 'premiums'],
            kind='reg',
            palette='BrBG',
            diag_kind='kde',
            hue='Region')

plt.show()

# %% [markdown]
# ## **Using JointGrid and jointplot**

# %% [markdown]
# #### **Building a JointGrid and jointplot**

# %%
# Build a JointGrid comparing humidity and total_rentals
sns.set_style("whitegrid")
g = sns.JointGrid(x="hum",
                  y="total_rentals",
                  data=bike_share,
                  xlim=(0.1, 1.0))

g.plot(sns.regplot, sns.histplot)

plt.show()

# %%
# Create a jointplot similar to the JointGrid
sns.jointplot(x="hum",
             y="total_rentals",
             kind="reg",
             data=bike_share)

plt.show()

# %% [markdown]
# #### **Jointplots and regression**

# %%
# Plot temp vs. total_rentals as a regression plot
sns.jointplot(x='temp',
             y='total_rentals',
             kind='reg',
             data=bike_share,
             order=2,
             xlim=(0, 1))

# %%
# Plot a jointplot showing the residuals
sns.jointplot(x='temp',
             y='total_rentals',
             kind='resid',
             data=bike_share,
             order=2)

# %% [markdown]
# #### **Complex jointplots**

# %%
# Create a jointplot of temp vs. casual riders
# Include a kdeplot over the scatter plot
g = sns.jointplot(x='temp', y='casual',
                  kind='scatter',
                  data=bike_share,
                  marginal_kws=dict(bins=10, rug=True))

# Overlay a kdeplot on the scatter plot
g.plot_joint(sns.kdeplot)

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:2214: UserWarning: The marginal plotting function has changed to `histplot`, which does not accept the following argument(s): rug.
#   warnings.warn(msg, UserWarning)

# %%
# Replicate the above plot but only for registered riders
# Create a jointplot of temp vs. registered riders
g = sns.jointplot(x='temp', y='registered',
                  kind='scatter',
                  data=bike_share,
                  marginal_kws=dict(bins=10, rug=True))

# Overlay a kdeplot on the scatter plot
g.plot_joint(sns.kdeplot)

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:2214: UserWarning: The marginal plotting function has changed to `histplot`, which does not accept the following argument(s): rug.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# #### $\color{skyblue}{\textbf{Connect with me:}}$
#
#
# [<img align="left" src="https://cdn4.iconfinder.com/data/icons/social-media-icons-the-circle-set/48/twitter_circle-512.png" width="32px"/>][twitter]
# [<img align="left" src="https://cdn-icons-png.flaticon.com/512/145/145807.png" width="32px"/>][linkedin]
# [<img align="left" src="https://cdn2.iconfinder.com/data/icons/whcompare-blue-green-web-hosting-1/425/cdn-512.png" width="32px"/>][Portfolio]
#
# [twitter]: https://twitter.com/F4izy
# [linkedin]: https://www.linkedin.com/in/mohd-faizy/
# [Portfolio]: https://mohdfaizy.com/
