# %% [markdown]
# # <center>📉**Introduction to Seaborn**📈</center>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ###🔴**Dataset**🔴

# %%
url_countries = 'https://raw.githubusercontent.com/mohd-faizy/CAREER-TRACK-Data-Scientist-with-Python/main/07_Introduction%20to%20Data%20Visualization%20with%20Seaborn/_dataset/countries-of-the-world.csv'
url_mpg = 'https://raw.githubusercontent.com/mohd-faizy/CAREER-TRACK-Data-Scientist-with-Python/main/07_Introduction%20to%20Data%20Visualization%20with%20Seaborn/_dataset/mpg.csv'
url_student = 'https://raw.githubusercontent.com/mohd-faizy/CAREER-TRACK-Data-Scientist-with-Python/main/07_Introduction%20to%20Data%20Visualization%20with%20Seaborn/_dataset/student-alcohol-consumption.csv'
url_survey_responses = 'https://raw.githubusercontent.com/mohd-faizy/CAREER-TRACK-Data-Scientist-with-Python/main/07_Introduction%20to%20Data%20Visualization%20with%20Seaborn/_dataset/young-people-survey-responses.csv'

# %%
countries = pd.read_csv(url_countries)
mpg= pd.read_csv(url_mpg)
student_data = pd.read_csv(url_student)
survey_data = pd.read_csv(url_survey_responses)

# %%
df_list = [countries, mpg, student_data, survey_data]
df_name = ['countries', 'mpg', 'student_data', 'survey_data']
for items, name in zip(df_list, df_name):
    print(name)
    print('-'*100)
    print(items.columns)
    print('-'*100)
# Out:
# countries
# ----------------------------------------------------------------------------------------------------
# Index(['Country', 'Region', 'Population', 'Area (sq. mi.)',
#        'Pop. Density (per sq. mi.)', 'Coastline (coast/area ratio)',
#        'Net migration', 'Infant mortality (per 1000 births)',
#        'GDP ($ per capita)', 'Literacy (%)', 'Phones (per 1000)', 'Arable (%)',
#        'Crops (%)', 'Other (%)', 'Climate', 'Birthrate', 'Deathrate',
#        'Agriculture', 'Industry', 'Service'],
#       dtype='object')
# ----------------------------------------------------------------------------------------------------
# mpg
# ----------------------------------------------------------------------------------------------------
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')
# ...

# %%
sns.load_dataset('tips').columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %% [markdown]
# ## 1️⃣**Introduction to Seaborn**

# %% [markdown]
# ### **Making a scatter plot with lists**

# %%
countries.columns
# Out:
# Index(['Country', 'Region', 'Population', 'Area (sq. mi.)',
#        'Pop. Density (per sq. mi.)', 'Coastline (coast/area ratio)',
#        'Net migration', 'Infant mortality (per 1000 births)',
#        'GDP ($ per capita)', 'Literacy (%)', 'Phones (per 1000)', 'Arable (%)',
#        'Crops (%)', 'Other (%)', 'Climate', 'Birthrate', 'Deathrate',
#        'Agriculture', 'Industry', 'Service'],
#       dtype='object')

# %%
def clean_data(data):
    return list(map(lambda x: float(x.replace(',', '.')), data.astype(str)))

gdp = clean_data(countries['GDP ($ per capita)'])
phones = clean_data(countries['Phones (per 1000)'])
percent_literate = clean_data(countries['Literacy (%)'])

# %%
# Create scatter plot with GDP on the x-axis and number of phones on the y-axis
sns.scatterplot(x=gdp, y=phones)

# Change this scatter plot to have percent literate on the y-axis
sns.scatterplot(x=gdp, y=percent_literate)

# Show plot
plt.show()

# %%
# Change this scatter plot to have percent literate on the y-axis
sns.scatterplot(x=gdp, y=percent_literate)

# Show plot
plt.show()

# %% [markdown]
# ### **Making a count plot with a list**

# %%
# Create count plot with region on the y-axis
sns.countplot(y=countries['Region'])

# Show plot
plt.show()

# %% [markdown]
# ### **"Tidy" vs. "untidy" data**

# %% [markdown]
# ### **Making a count plot with a DataFrame**

# %%
# Create a count plot with "Spiders" on the x-axis
sns.countplot(x='Spiders', data=survey_data)

# Display the plot
plt.show()

# %% [markdown]
# ### **Hue and scatter plots**

# %%
# Load the tips dataset
tips = sns.load_dataset('tips')

# Create a scatter plot
sns.scatterplot(x='total_bill', y='tip', data=tips)
plt.show()

# %%
# Setting the hue
sns.scatterplot(x='total_bill', y='tip', data=tips, hue='smoker')
plt.show()

# %%
# Setting the hue order
sns.scatterplot(x='total_bill', y='tip', data=tips, hue='smoker', hue_order=['No', 'Yes'])
plt.show()

# %%
# Create a scatter plot of absences vs. final grade
sns.scatterplot(x='absences',
                y='G3',
                data=student_data,
                hue='location'
                )

# Show plot
plt.show()


# Change the legend order in the scatter plot
sns.scatterplot(x="absences", y="G3", 
                data=student_data, 
                hue="location",
                hue_order=['Rural', 'Urban'])

# Show plot
plt.show()

# %% [markdown]
# ### **Hue and count plots**

# %%
# Create a dictionary mapping subgroup values to colors
palette_colors = {"Rural": "crimson",
                  "Urban": "skyblue"}

# Create a count plot of school with location subgroups
sns.countplot(x="school",
                data=student_data,
                hue="location",
                palette=palette_colors)


# Display plot
plt.show()

# %% [markdown]
# ## 2️⃣**Visualizing Two Quantitative Variables** - **Relational plots**

# %% [markdown]
# ### **Scatter**

# %% [markdown]
# ### **Creating subplots with col and row**

# %%
# Load the tips dataset
tips = sns.load_dataset('tips')

# Create a scatter plot
sns.relplot(x='total_bill', y='tip',
            data=tips,
            kind='scatter')

plt.show()

# %%
# Load the tips dataset
tips = sns.load_dataset('tips')

# Create a scatter plot
sns.relplot(x='total_bill', y='tip',
            data=tips,
            kind='scatter',
            col='smoker') # row ='smoker' to arrange them vertically

plt.show()

# %%
# Load the tips dataset
tips = sns.load_dataset('tips')

# Create a scatter plot
sns.relplot(x='total_bill', y='tip',
            data=tips,
            kind='scatter',
            col='smoker',
            row='time')

plt.show()

# %%
# Load the tips dataset
tips = sns.load_dataset('tips')

# Create a scatter plot
sns.relplot(x='total_bill', y='tip',
            data=tips,
            kind='scatter',
            col='day',
            # col_wrap=2
            )

plt.show()

# %%
# Load the tips dataset
tips = sns.load_dataset('tips')

# Create a scatter plot
sns.relplot(x='total_bill', y='tip',
            data=tips,
            kind='scatter',
            col='day',
            col_wrap=2,
            col_order=['Thur', 'Fri', 'Sat', 'Sun']
            )

plt.show()

# %%
# 1 - Modify the code to use relplot instead of scatterplot
sns.relplot(x="absences", y="G3",
            data=student_data,
            kind="scatter")

# Show plot
plt.show()
print('\n')

# 2 - Modify the code to create one scatter plot for each level of the variable 
# "study_time", arranged in columns.
# Change to make subplots based on study time
sns.relplot(x="absences", y="G3",
            data=student_data,
            kind="scatter",
            col="study_time")

# Show plot
plt.show()
print('\n')

# 3 - Adapt your code to create one scatter plot for each level of a student's weekly 
# study time, this time arranged in rows.
# Change this scatter plot to arrange the plots in rows instead of columns
sns.relplot(x="absences", y="G3",
            data=student_data,
            kind="scatter",
            row="study_time")

# Show plot
plt.show()

# %% [markdown]
# ### **Creating two-factor subplots**

# %%
# Create a scatter plot of G1 vs. G3
sns.relplot(x="G1", y="G3",
            data=student_data,
            kind="scatter",
            )

# Show plot
plt.show()
print('\n')


# Adjust to add subplots based on school support
sns.relplot(x="G1", y="G3",
            data=student_data,
            kind="scatter",
            col="schoolsup",
            col_order=["yes", "no"])

# Show plot
plt.show()
print('\n')


# Adjust further to add subplots based on family support
sns.relplot(x="G1", y="G3",
            data=student_data,
            kind="scatter",
            col="schoolsup",
            col_order=["yes", "no"],
            row="famsup",
            row_order=["yes", "no"])

# Show plot
plt.show()

# %% [markdown]
# ### **Changing the size of scatter plot points**

# %%
# Dataset Tips
# Plot size and Hue
sns.relplot(x='total_bill', y='tip',
            data=tips,
            kind='scatter',
            size='size')

plt.show()
print('\n')

sns.relplot(x='total_bill', y='tip',
            data=tips,
            kind='scatter',
            size='size',
            hue='size')
plt.show()

# %%
# Dataset mpg
# Create scatter plot of horsepower vs. mpg
sns.relplot(x='horsepower',
            y='mpg',
            data=mpg,
            kind='scatter',
            size='cylinders')

# Show plot
plt.show()
print('\n')

# Create scatter plot of horsepower vs. mpg
sns.relplot(x="horsepower",
            y="mpg", 
            data=mpg,
            kind="scatter", 
            size="cylinders",
            hue="cylinders")

# Show plot
plt.show()

# %% [markdown]
# Cars with higher horsepower tend to get a lower number of miles per gallon. They also tend to have a higher number of cylinders

# %% [markdown]
# ### **Changing the style of scatter plot points**

# %%
# For Tips dataset
sns.relplot(x='total_bill', y='tip',
            data=tips,
            kind='scatter',
            size='smoker',
            hue='smoker',
            style='smoker')
plt.show()

# %%
# datset mpg
# Create a scatter plot of acceleration vs. mpg
sns.relplot(x='acceleration',
            y='mpg',
            data=mpg,
            kind='scatter',
            hue='origin',
            style='origin')

# Show plot
plt.show()

# %% [markdown]
# Cars from the USA tend to accelerate more quickly and get lower miles per gallon compared to cars from Europe and Japan.

# %% [markdown]
# ### **Line Plot**

# %% [markdown]
# ### **Interpreting line plots**

# %%
# How has the average miles per gallon achieved by these cars changed over time?
# Create line plot
sns.relplot(x='model_year', y='mpg',
            data=mpg,
            kind='line')

# Show plot
plt.show()

# %% [markdown]
# The shaded region represents a confidence interval for the mean, not the distribution of the observations.

# %% [markdown]
# ### **Visualizing standard deviation with line plots**

# %%
# Change the plot so the shaded area shows the standard deviation instead of the confidence interval for the mean.
sns.relplot(x="model_year", y="mpg",
            data=mpg,
            kind="line",
            errorbar='sd') # ci='sd' is deprecated use errorbar

# Show plot
plt.show()

# %% [markdown]
# ### **Plotting subgroups in line plots**

# %%
# Create line plot of model year vs. horsepower
sns.relplot(x='model_year',
            y='horsepower',
            data=mpg,
            kind='line',
            errorbar=None)

# Show plot
plt.show()

# %%
# Change to create subgroups for country of origin
sns.relplot(x="model_year",
            y="horsepower", 
            data=mpg,
            kind="line",
            hue='origin',
            style='origin',
            errorbar=None)

# Show plot
plt.show()

# %%
# Add markers and make each line have the same style
sns.relplot(x="model_year",
            y="horsepower", 
            data=mpg,
            kind="line", 
            errorbar=None,
            style="origin", 
            hue="origin",
            markers=True, 
            dashes=False )

# Show plot
plt.show()

# %% [markdown]
# ## 3️⃣**Visualizing a Categorical and a Quantitative Variable**

# %% [markdown]
# ### **Count plots**

# %%
# Create count plot of internet usage
sns.catplot(x='Internet usage',
            data=survey_data,
            kind='count')

# Show plot
plt.show()

# %%
# Change the orientation of the plot
sns.catplot(y="Internet usage",
            data=survey_data,
            kind="count")

# Show plot
plt.show()

# %%
# Create the age category column
survey_data['Age'] = pd.cut(survey_data['Age'], bins=[0, 20, float('inf')], labels=['less than 21', '21 plus'])

# Create column subplots based on age category
sns.catplot(y="Internet usage",
            data=survey_data,
            kind="count",
            col='Age')

# Show plot
plt.show()

# %% [markdown]
# ### **Bar plots with percentages**

# %%
# Create a bar plot of interest in math, separated by gender
sns.catplot(x='Gender',
            y="Mathematics",
            data=survey_data,
            kind="bar")

# Show plot
plt.show()

# %% [markdown]
# ### **Customizing bar plots**

# %%
# Create bar plot of average final grade in each study category
sns.catplot(x='study_time', y="G3",
            data=student_data,
            kind="bar")

# Show plot
plt.show()

# %%
# Rearrange the categories
sns.catplot(x="study_time", y="G3",
            data=student_data,
            kind="bar",
            order=["<2 hours",
                   "2 to 5 hours",
                   "5 to 10 hours",
                   ">10 hours"])

# Show plot
plt.show()

# %%
# Turn off the confidence intervals
sns.catplot(x="study_time", y="G3",
            data=student_data,
            kind="bar",
            order=["<2 hours",
                   "2 to 5 hours",
                   "5 to 10 hours",
                   ">10 hours"],
            errorbar=None)

# Show plot
plt.show()

# %% [markdown]
# ### **Create and interpret a box plot**

# %%
# Specify the category ordering
study_time_order = ["<2 hours", "2 to 5 hours",
                    "5 to 10 hours", ">10 hours"]

# Create a box plot and set the order of the categories
sns.catplot(x='study_time',
            y='G3',
            data=student_data,
            kind='box',
            order=study_time_order)

# Show plot
plt.show()

# %% [markdown]
# ### **Omitting outliers**

# %%
# Create a box plot with subgroups and omit the outliers
sns.catplot(x='internet',
            y='G3',
            data=student_data,
            kind='box',
            sym='',
            hue='location')

# Show plot
plt.show()

# %% [markdown]
# ### **Adjusting the whiskers**

# %%
# Set the whiskers to 0.5 * IQR
sns.catplot(x="romantic", y="G3",
            data=student_data,
            kind="box",
            whis=0.5)

# Show plot
plt.show()

# %%
# Extend the whiskers to the 5th and 95th percentile
sns.catplot(x="romantic", y="G3",
            data=student_data,
            kind="box",
            whis=[5, 95])

# Show plot
plt.show()

# %%
# Set the whiskers at the min and max values
sns.catplot(x="romantic", y="G3",
            data=student_data,
            kind="box",
            whis=[0, 100])

# Show plot
plt.show()

# %% [markdown]
# ### **Customizing point plots**

# %% [markdown]
# **`Point plots` vs. `line plots`**
#
# **Both show:**
# - Mean of quantitative variable
# - 95% confidence intervals for the mean
#
# **Differences:**
# - Line plot has quantitative variable (usually time) on x-axis
# - Point plot has categorical variable on x-axis

# %% [markdown]
# **`Point plots` vs. `bar plots`**
#
# **Both show:**
# - Mean of quantitative variable
# - 95% confidence intervals for the mean

# %%
# Create a point plot of family relationship vs. absences
sns.catplot(x="famrel", y="absences",
            data=student_data,
            kind="point")

# Show plot
plt.show()

# %%
# Add caps to the confidence interval
sns.catplot(x="famrel", y="absences",
            data=student_data,
            kind="point",
            capsize=0.2)

# Show plot
plt.show()

# %% [markdown]
# By setting `capsize=0.2`, you are specifying that the length of the caps should be 0.2 times the width of the point estimate. This parameter allows you to control the visual appearance of the caps in relation to the point estimate.

# %%
# Remove the lines joining the points
sns.catplot(x="famrel", y="absences",
            data=student_data,
            kind="point",
            capsize=0.2,
            join=False)

# Show plot
plt.show()

# %% [markdown]
# hile the average number of absences is slightly smaller among students with higher-quality family relationships, the large confidence intervals tell us that we can't be sure there is an actual association here.

# %% [markdown]
# ### **Point plots with subgroups**

# %%
# Create a point plot with subgroups
sns.catplot(x="romantic", y="absences",
            data=student_data,
            kind="point",
            hue='school'
            )

# Show plot
plt.show()

# %%
# Turn off the confidence intervals for this plot
sns.catplot(x="romantic", y="absences",
            data=student_data,
            kind="point",
            hue="school",
            errorbar=None)

# Show plot
plt.show()

# %%
# Plot the median number of absences instead of the mean
sns.catplot(x="romantic", y="absences",
			data=student_data,
            kind="point",
            hue="school",
            errorbar=None,
            estimator=np.median)

# Show plot
plt.show()

# %% [markdown]
# ## 4️⃣**Customizing Seaborn Plots**

# %%
survey_data.head(3)
# Out:
#    Unnamed: 0  Music  Techno  Movies  History  Mathematics  Pets  Spiders  \
# 0           0    5.0     1.0     5.0      1.0          3.0   4.0      1.0
# 1           1    4.0     1.0     5.0      1.0          5.0   5.0      1.0
# 2           2    5.0     1.0     5.0      1.0          5.0   5.0      1.0
#
#    Loneliness  Parents' advice   Internet usage  Finances           Age  \
# 0         3.0              4.0  few hours a day       3.0  less than 21
# 1         2.0              2.0  few hours a day       3.0  less than 21
# 2         5.0              3.0  few hours a day       2.0  less than 21
#
#    Siblings  Gender Village - town
# 0       1.0  female        village
# 1       2.0  female           city
# 2       2.0  female           city

# %% [markdown]
# ### **Changing style and palette**

# %%
# Load the tips dataset
tips_data = sns.load_dataset("tips")

# Set the style
sns.set_style('whitegrid')


# Set the Pallete
# sns.set_palette("YlOrBr")
# sns.set_palette("Purples")
sns.set_palette("RdBu")

# Define the category order for gender and smoker columns
gender_order = ["Male", "Female"]
smoker_order = ["Yes", "No"]

# Create a count plot of gender and smoker
sns.catplot(x='sex',
            hue='smoker',
            data=tips_data,
            kind="count",
            order=gender_order,
            hue_order=smoker_order)

# Set the x-axis label
plt.xlabel('Gender')

# Set the y-axis label
plt.ylabel('Count')

# Set the plot title
plt.title('Count of Male and Female by Smoker Status')

# Show the plot
plt.show()

# %% [markdown]
# ### **Changing the scale**

# %%
# Load the iris dataset
iris_data = sns.load_dataset('iris')

# Set the context
context_list = ['paper', 'notebook', 'talk', 'poster']

for item in context_list:
    sns.set_context(item)
    # Create bar plot
    sns.catplot(x="species",
                y="sepal_width",
                data=iris_data,
                kind="bar")

    # Show plot
    print(item)
    plt.show()
    print('\n')
# Out:
# paper
# notebook
# talk
# poster

# %% [markdown]
# ### **Using a custom palette**

# %%
# Load the iris dataset
iris_data = sns.load_dataset('iris')

sns.set_context('notebook')

# Set the style to "darkgrid"
sns.set_style("darkgrid")

# Set a custom color palette
custom_palette = ["#39A7D0", "#36ADA4"]
sns.set_palette(custom_palette)

# Create the box plot of sepal length distribution by species
sns.catplot(x="species", y="sepal_length",
            data=iris_data, kind="box")

# Show plot
plt.show()

# %% [markdown]
# ### **`FacetGrids` vs. `AxesSubplots`**
#
# #### **FacetGrids:**
#
# - FacetGrids are part of the seaborn library and are specifically designed for creating grids of plots based on one or more categorical variables.
# - FacetGrids allow you to easily create a grid of subplots, where each subplot  represents a unique combination of the categories in the specified variables.
# - FacetGrids are especially useful when you want to visualize relationships - between variables across different subsets of your data.
# - FacetGrids provide built-in capabilities for handling categorical variables,  including options for row and column facets, and hue variables for color - encoding.
# - They provide additional functionality such as the ability to apply different  plot types to each subplot, apply statistical functions, and more.
#
#
# #### **AxesSubplots:**
#
# - AxesSubplots are part of the matplotlib library and provide a way to manually create and arrange subplots in a single figure.
# - AxesSubplots give you more fine-grained control over the layout and - customization of individual subplots within a figure.
# - They are suitable for creating a variety of plot layouts, including grids, - rows, columns, or any custom arrangement you desire.
# - With AxesSubplots, you need to explicitly define the positions and sizes of - each subplot in the figure, which gives you more flexibility but requires more  manual adjustments.
#
# |Object|Plot type|Characteristics|
# |------|---------|---------------|
# |`FacetGrid`|`relplot()`, `catplot()`|Can create Subplots|
# |`AxesSubplot`|`scatterplot()`, `countplot()` etc|Only creates a single plot|

# %%
plt.style.use('ggplot')

# Load the tips dataset
tips_data = sns.load_dataset("tips")

# Create a FacetGrid with two facets based on the "time" variable
g = sns.FacetGrid(data=tips_data, col="time")

# Map a scatter plot onto the FacetGrid
g.map(sns.scatterplot, "total_bill", "tip")

# Show the plot
plt.show()

# %%
# Create scatter plot
g = sns.relplot(x="weight",
                y="horsepower",
                data=mpg,
                kind="scatter")

# Identify plot type
type_of_g = type(g)

# Print type
print(type_of_g)
# Out:
# <class 'seaborn.axisgrid.FacetGrid'>

# %%
# AxesSubplots
# Create a figure with two subplots
fig, axs = plt.subplots(1, 2)

# Generate random data
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

# Plot data on the first subplot
axs[0].plot(x, y1)
axs[0].set_title('Sin(x)')

# Plot data on the second subplot
axs[1].plot(x, y2)
axs[1].set_title('Cos(x)')

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ### **Adding a title to a FacetGrid object**

# %%
# Create scatter plot
g = sns.relplot(x="weight",
                y="horsepower",
                data=mpg,
                kind="scatter")

# Add a title "Car Weight vs. Horsepower"
g.fig.suptitle("Car Weight vs. Horsepower")

# Show plot
plt.show()

# %% [markdown]
# ### **Adding a title and axis labels**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the style to "whitegrid"
sns.set_style('whitegrid')

# Load the flights dataset
flights_data = sns.load_dataset("flights")

# Create line plot
g = sns.lineplot(x="year", y="passengers",
                 data=flights_data)


g.set_title('Passenger Count Over Time')

# Add x-axis and y-axis labels
g.set(xlabel="Year",
      ylabel="Passenger Count")

# Show the plot
plt.show()

# %% [markdown]
# ### **Rotating x-tick labels**

# %%
# Create point plot
sns.catplot(x="origin",
            y="acceleration",
            data=mpg,
            kind="point",
            join=False,
            capsize=0.1)

# Rotate x-tick labels
plt.xticks(rotation=90)

# Show plot
plt.show()

# %% [markdown]
# ### **Box plot with subgroups**

# %%
# Set palette to "Blues"
sns.set_palette("Blues")

# Load the titanic dataset
titanic_data = sns.load_dataset("titanic")

# Adjust to add subgroups based on "class"
g = sns.catplot(x="sex",
                y="age",
                data=titanic_data,
                kind="box",
                hue="class")

# Set title to "Age of Passengers by Class"
g.fig.suptitle("Age of Passengers by Class")

# Show plot
plt.show()

# %% [markdown]
# ### **Bar plot with subgroups and subplots**

# %%
# set style using matplotlib
plt.style.use('ggplot')

# Set the figure style to "dark"
sns.set_style("dark")

# Adjust to add subplots per gender
g = sns.catplot(x="Village - town", y="Techno",
                data=survey_data, kind="bar",
                col="Gender")

# Add title and axis labels
g.fig.suptitle("Percentage of Young People Who Like Techno", y=1.02)
g.set(xlabel="Location of Residence",
      ylabel="% Who Like Techno")

# Show plot
plt.show()

# %% [markdown]
# ## 📊**Where to go next**

# %% [markdown]
# - **Relational Plots:** Shows the relationship between two quantitative variables.
#     - Examples:
#         - **scatter plots**
#         - **line plot**
#
# - **Categorical Plots:** Show the distribution of a quantitative variable within categories defined by a categorical variable.
#     - Examples:
#         - **bar plots**
#         - **count plots**
#         - **box plots**
#         - **point plots**

# %%
# set style using matplotlib
plt.style.use('ggplot')
sns.set_context('notebook')

# Initial plot
iris_df = sns.load_dataset("iris")
sns.relplot(data=iris_df, x="sepal_length", y="sepal_width", kind='scatter',  hue="species")
plt.show()

print("\n")

# Initial plot
iris_df = sns.load_dataset("iris")
sns.scatterplot(data=iris_df, x="sepal_length", y="sepal_width", hue="species")
plt.show()
print("\n")


# Initial plot
iris_df = sns.load_dataset("iris")
sns.relplot(data=iris_df, x="sepal_length", y="sepal_width", kind='line',  hue="species", errorbar=None)
plt.show()

print("\n")

# %%
# set style using matplotlib
plt.style.use('ggplot')
sns.set_context('notebook')

# Load the dataset
titanic = sns.load_dataset("titanic")

# Create a bar plot
sns.catplot(data=titanic, x="class", y="fare", hue="survived", kind="bar")
# sns.catplot(data=titanic, x="class", hue="survived", kind="count")
# sns.catplot(data=titanic, x="class", y="fare", hue="survived", kind="box")
# sns.catplot(data=titanic, x="class", y="fare", hue="survived", kind="point", join=False)
plt.show()

# %% [markdown]
# **Customization**
#
# - Change the **Background**: `sns.set_style()`
# - Change the **Main Element Colors**: `sns.set_patette()`
# - Change the **Scale**: `sns.set_context()`

# %% [markdown]
# **Adding a title**
#
# |Object Type|Plot Types|How to Add Title|
# |------|----------|----------------|
# |FacetGrid|`relplot()`,`catptot()`|`g.fig.suptitte()`|
# |AxesSubpLot|`scatterplot()`, `countplot()`|`g.set_title()`|

# %% [markdown]
# - [Seaborn](https://seaborn.pydata.org/)

# %% [markdown]
# #### $\color{skyblue}{\textbf{Connect with me:}}$
#
#
# [<img align="left" src="https://cdn4.iconfinder.com/data/icons/social-media-icons-the-circle-set/48/twitter_circle-512.png" width="32px"/>][twitter]
# [<img align="left" src="https://cdn-icons-png.flaticon.com/512/145/145807.png" width="32px"/>][linkedin]
# [<img align="left" src="https://cdn2.iconfinder.com/data/icons/whcompare-blue-green-web-hosting-1/425/cdn-512.png" width="32px"/>][Portfolio]
#
# [twitter]: https://twitter.com/F4izy
# [linkedin]: https://www.linkedin.com/in/mohd-faizy/
# [Portfolio]: https://mohdfaizy.com/
