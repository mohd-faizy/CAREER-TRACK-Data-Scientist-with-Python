# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## ⭐**Datasets**:

# %% [markdown]
# ### **chicago_dataset**

# %%
import pandas as pd
import requests

data_list = ["ward.p", "licenses.p", "census.p", "zip_demo.p", "business_owners.p", "land_use.p", "taxi_vehicles.p", "taxi_owners.p", "Ward_Offices.csv"]

# Loop through the list of file names
for file_name in data_list:
    # Construct the URL
    url = f"https://github.com/mohd-faizy/CAREER-TRACK-Data-Scientist-with-Python/raw/main/06_Joining%20Data%20with%20pandas/_datasets/Chicago/{file_name}"
    
    # Download the file from URL and save locally
    response = requests.get(url)
    with open(file_name, "wb") as f:
        f.write(response.content)
    
    # Read the local file into a DataFrame based on file type
    if file_name.endswith(".p"):
        # For pickle files
        df = pd.read_pickle(file_name)
    elif file_name.endswith(".csv"):
        # For CSV files
        df = pd.read_csv(file_name)
    else:
        # For other file types, you may need to use a different function to read the file
        print(f"Unknown file type: {file_name}")
        continue
    
    # Display DataFrame
    print(f"DataFrame from {file_name}:")
    display(df.head(2))
    print(df.shape)
    print("\n")
# Out:
# DataFrame from ward.p:
#   ward            alderman                     address    zip
# 0    1  Proco "Joe" Moreno   2058 NORTH WESTERN AVENUE  60647
# 1    2       Brian Hopkins  1400 NORTH  ASHLAND AVENUE  60622
# (50, 4)
#
#
# DataFrame from licenses.p:
#   account ward  aid              business              address    zip
# 0  307071    3  743  REGGIE'S BAR & GRILL      2105 S STATE ST  60616
# 1      10   10  829            HONEYBEERS  13200 S HOUSTON AVE  60633
# (10000, 6)
#
#
# DataFrame from census.p:
#   ward  pop_2000  pop_2010 change                      address    zip
# 0    1     52951     56149     6%  2765 WEST SAINT MARY STREET  60647
# 1    2     54361     55805     3%     WM WASTE MANAGEMENT 1500  60622
# (50, 6)
#
#
# DataFrame from zip_demo.p:
#      zip  income
# 0  60630   70122
# 1  60640   50488
# (66, 2)
#
#
# DataFrame from business_owners.p:
#   account first_name last_name      title
# 0      10      PEARL   SHERMAN  PRESIDENT
# ...

# %% [markdown]
# ### **movies_dataset**

# %%
import pandas as pd
import requests

data_list = ["actors_movies.csv", "casts.p", "crews.p", "financials.p", "movie_to_genres.p", "movies.p", "ratings.p", "sequels.p", "taglines.p"]


# Loop through the list of file names
for file_name in data_list:
    # Construct the URL
    url = f"https://github.com/mohd-faizy/CAREER-TRACK-Data-Scientist-with-Python/raw/main/06_Joining%20Data%20with%20pandas/_datasets/movies/{file_name}"
    
    # Download the file from URL and save locally
    response = requests.get(url)
    with open(file_name, "wb") as f:
        f.write(response.content)
    # Read the local file into a DataFrame based on file type
    if file_name.endswith(".p"):
        # For pickle files
        df = pd.read_pickle(file_name)
    elif file_name.endswith(".csv"):
        # For CSV files
        df = pd.read_csv(file_name)
    else:
        # For other file types, you may need to use a different function to read the file
        print(f"Unknown file type: {file_name}")
        continue

    
    # Display DataFrame
    print(f"DataFrame from {file_name}:")
    display(df.head(2))
    print(df.shape)
    print("\n")
# Out:
# DataFrame from actors_movies.csv:
#                                                Actor                Title
# 0  [Emil Eifrem,Hugo Weaving,Laurence Fishburne,C...           The Matrix
# 1  [Hugo Weaving,Laurence Fishburne,Carrie-Anne M...  The Matrix Reloaded
# (35, 2)
#
#
# DataFrame from casts.p:
#    movie_id  cast_id character  gender    id               name
# 7         5       22   Jezebel       1  3122        Sammi Davis
# 8         5       23     Diana       1  3123  Amanda de Cadenet
# (106257, 6)
#
#
# DataFrame from crews.p:
#       id department             job               name
# 0  19995    Editing          Editor  Stephen E. Rivkin
# 2  19995      Sound  Sound Designer  Christopher Boyes
# (42502, 4)
#
#
# DataFrame from financials.p:
#       id     budget       revenue
# 0  19995  237000000  2.787965e+09
# 1    285  300000000  9.610000e+08
# (3229, 3)
#
#
# DataFrame from movie_to_genres.p:
#    movie_id   genre
# 0         5   Crime
# 1         5  Comedy
# ...

# %% [markdown]
# ### **CTA_dataset**

# %%
import pandas as pd
import requests

data_list = ["cta_calendar.p", "cta_ridership.p", "stations.p"]

# Loop through the list of file names
for file_name in data_list:
    # Construct the URL
    url = f"https://github.com/mohd-faizy/CAREER-TRACK-Data-Scientist-with-Python/raw/main/06_Joining%20Data%20with%20pandas/_datasets/cta/{file_name}"
    
    # Download the file from URL and save locally
    response = requests.get(url)
    with open(file_name, "wb") as f:
        f.write(response.content)
    # Read the local file into a DataFrame based on file type
    if file_name.endswith(".p"):
        # For pickle files
        df = pd.read_pickle(file_name)
    elif file_name.endswith(".csv"):
        # For CSV files
        df = pd.read_csv(file_name)
    else:
        # For other file types, you may need to use a different function to read the file
        print(f"Unknown file type: {file_name}")
        continue

    
    # Display DataFrame
    print(f"DataFrame from {file_name}:")
    display(df.head(2))
    print(df.shape)
    print("\n")
# Out:
# DataFrame from cta_calendar.p:
#    year  month  day        day_type
# 0  2019      1    1  Sunday/Holiday
# 1  2019      1    2         Weekday
# (365, 4)
#
#
# DataFrame from cta_ridership.p:
#   station_id  year  month  day  rides
# 0      40010  2019      1    1    576
# 1      40010  2019      1    2   1457
# (3285, 5)
#
#
# DataFrame from stations.p:
#   station_id        station_name                 location
# 0      40010  Austin-Forest Park  (41.870851, -87.776812)
# 1      40020         Harlem-Lake  (41.886848, -87.803176)
# (144, 3)

# %% [markdown]
# ### **SNP500_dataset**

# %%
df_snp500 = pd.read_csv("https://raw.githubusercontent.com/mohd-faizy/CAREER-TRACK-Data-Scientist-with-Python/main/06_Joining%20Data%20with%20pandas/_datasets/S%26P500/S%26P500.csv")
df_snp500.head(2)
# Out:
#    Date  Returns
# 0  2008   -38.49
# 1  2009    23.45

# %% [markdown]
# ### **worldbank_datset**

# %%
url_gdp = "https://raw.githubusercontent.com/mohd-faizy/CAREER-TRACK-Data-Scientist-with-Python/main/06_Joining%20Data%20with%20pandas/_datasets/WorldBank_GDP/WorldBank_GDP.csv"
url_pop = "https://raw.githubusercontent.com/mohd-faizy/CAREER-TRACK-Data-Scientist-with-Python/main/06_Joining%20Data%20with%20pandas/_datasets/WorldBank_GDP/WorldBank_POP.csv"

df_worldbank_gdp = pd.read_csv(url_gdp)
df_worldbank_pop = pd.read_csv(url_pop)

display(df_worldbank_gdp.head(2))
print("\n")
display(df_worldbank_pop.head(2))
# Out:
#   Country Name Country Code     Indicator Name  Year           GDP
# 0        China          CHN  GDP (current US$)  2010  6.087160e+12
# 1      Germany          DEU  GDP (current US$)  2010  3.417090e+12
#   Country Name Country Code     Indicator Name  Year         Pop
# 0        Aruba          ABW  Population, total  2010    101669.0
# 1  Afghanistan          AFG  Population, total  2010  29185507.0

# %% [markdown]
# ### **crime_dataset**

# %%
url_crime = "https://raw.githubusercontent.com/mohd-faizy/CAREER-TRACK-Data-Scientist-with-Python/main/06_Joining%20Data%20with%20pandas/_datasets/Crime_Types.csv"
df_crime = pd.read_csv(url_crime)

df_crime.head(2)
# Out:
#   FBI code                Name  \
# 0      04A  Aggravated assault
# 1      04B  Aggravated battery
#
#                                     Legal Definition  \
# 0  An unlawful attack by one person upon another ...
# 1  An unlawful attack by one person upon another ...
#
#                                  Friendly Definition
# 0  Credibly threatening to hit someone with the i...
# 1  Hitting someone and causing severe injury - su...

# %% [markdown]
# # 🟥**1. Data Merging Basics**

# %% [markdown]
# ### **inner join**

# %%
taxi_owners  = pd.read_pickle("/content/taxi_owners.p")
taxi_veh = pd.read_pickle("/content/taxi_vehicles.p")

# %%
# Merge the taxi_owners and taxi_veh tables
taxi_own_veh = taxi_owners.merge(taxi_veh, on='vid')
display(taxi_own_veh.head(4))
print("-"*120)

# Merge the taxi_owners and taxi_veh tables setting a suffix
taxi_own_veh = taxi_owners.merge(taxi_veh, on='vid', suffixes=('_own', '_veh'))
display(taxi_own_veh.head(4))
# Out:
#      rid   vid         owner_x                 address    zip    make   model  \
# 0  T6285  6285  AGEAN TAXI LLC     4536 N. ELSTON AVE.  60630  NISSAN  ALTIMA
# 1  T4862  4862    MANGIB CORP.  5717 N. WASHTENAW AVE.  60659   HONDA     CRV
# 2  T1495  1495   FUNRIDE, INC.     3351 W. ADDISON ST.  60618  TOYOTA  SIENNA
# 3  T4231  4231    ALQUSH CORP.   6611 N. CAMPBELL AVE.  60645  TOYOTA   CAMRY
#
#    year fuel_type         owner_y
# 0  2011    HYBRID  AGEAN TAXI LLC
# 1  2014  GASOLINE    MANGIB CORP.
# 2  2015  GASOLINE   FUNRIDE, INC.
# 3  2014    HYBRID    ALQUSH CORP.
# ------------------------------------------------------------------------------------------------------------------------
#      rid   vid       owner_own                 address    zip    make   model  \
# 0  T6285  6285  AGEAN TAXI LLC     4536 N. ELSTON AVE.  60630  NISSAN  ALTIMA
# 1  T4862  4862    MANGIB CORP.  5717 N. WASHTENAW AVE.  60659   HONDA     CRV
# ...

# %%
# Print the value_counts to find the most popular fuel_type
sns.countplot(x='fuel_type', data=taxi_own_veh)

# Set labels and title
plt.xlabel('Fuel Type')
plt.ylabel('Count')
plt.title('Fuel Type Distribution')
plt.xticks(rotation=50)
plt.show()

# %% [markdown]
# ### **Inner joins and number of rows returned**

# %%
ward  = pd.read_pickle("/content/ward.p")
census = pd.read_pickle("/content/census.p")

# %%
ward_census = ward.merge(census, on='ward')
display(ward_census.head(2))
print(ward_census.shape)
# Out:
#   ward            alderman                   address_x  zip_x  pop_2000  \
# 0    1  Proco "Joe" Moreno   2058 NORTH WESTERN AVENUE  60647     52951
# 1    2       Brian Hopkins  1400 NORTH  ASHLAND AVENUE  60622     54361
#
#    pop_2010 change                    address_y  zip_y
# 0     56149     6%  2765 WEST SAINT MARY STREET  60647
# 1     55805     3%     WM WASTE MANAGEMENT 1500  60622
# (50, 9)

# %% [markdown]
# ### **One-to-many merge**
#
# - The releationship Between `Product` and `inventory`: - `one` to `one`
# - The releationship Between `customer` and `cust_text_info`: - `one` to `one`
# - The releationship Between `customer` and `orders`: - `one` to `many`
# - The releationship Between `product` and `orders`: - `one` to `many`

# %%
licenses = pd.read_pickle("/content/licenses.p")
biz_owners = pd.read_pickle("/content/business_owners.p")

display(licenses.head(2))
display(biz_owners.head(2))
# Out:
#   account ward  aid              business              address    zip
# 0  307071    3  743  REGGIE'S BAR & GRILL      2105 S STATE ST  60616
# 1      10   10  829            HONEYBEERS  13200 S HOUSTON AVE  60633
#   account first_name last_name      title
# 0      10      PEARL   SHERMAN  PRESIDENT
# 1      10      PEARL   SHERMAN  SECRETARY

# %%
# Merge the licenses and biz_owners table on account
licenses_owners = licenses.merge(biz_owners, on='account')
display(licenses_owners.head(3))

# Group the results by title then count the number of accounts
counted_df = licenses_owners.groupby('title').agg({'account':'count'})
display(counted_df.head(3))

# Sort the counted_df in desending order
sorted_df = counted_df.sort_values(by='account', ascending=False)
display(sorted_df)
# Out:
#   account ward  aid              business              address    zip  \
# 0  307071    3  743  REGGIE'S BAR & GRILL      2105 S STATE ST  60616
# 1      10   10  829            HONEYBEERS  13200 S HOUSTON AVE  60633
# 2      10   10  829            HONEYBEERS  13200 S HOUSTON AVE  60633
#
#   first_name last_name      title
# 0     ROBERT     GLICK     MEMBER
# 1      PEARL   SHERMAN  PRESIDENT
# 2      PEARL   SHERMAN  SECRETARY
#                  account
# title
# ASST. SECRETARY      111
# BENEFICIARY            4
# CEO                  110
#                     account
# title
# PRESIDENT              6259
# SECRETARY              5205
# SOLE PROPRIETOR        1658
# OTHER                  1200
# VICE PRESIDENT          970
# MEMBER                  884
# MANAGING MEMBER         878
# SHAREHOLDER             590
# PARTNER                 451
# TREASURER               447
# INDIVIDUAL              268
# DIRECTOR                146
# MANAGER                 134
# ...

# %% [markdown]
# ### **Total riders in a month**

# %%
cal = pd.read_pickle("/content/cta_calendar.p")
ridership = pd.read_pickle("/content/cta_ridership.p")
stations = pd.read_pickle("/content/stations.p")

display(cal.head(1), ridership.head(1), stations.head(1))
# Out:
#    year  month  day        day_type
# 0  2019      1    1  Sunday/Holiday
#   station_id  year  month  day  rides
# 0      40010  2019      1    1    576
#   station_id        station_name                 location
# 0      40010  Austin-Forest Park  (41.870851, -87.776812)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Merge the ridership and cal tables
ridership_cal = ridership.merge(cal, on=['year', 'month', 'day'])
display(ridership_cal.head(3))

# Merge the ridership, cal, and stations tables
ridership_cal_stations = ridership_cal.merge(stations, on='station_id')
display(ridership_cal_stations.head(3))

# Create a filter to filter ridership_cal_stations
filter_criteria = ((ridership_cal_stations['month'] == 7) 
                   & (ridership_cal_stations['day_type'] == 'Weekday') 
                   & (ridership_cal_stations['station_name'] == 'Wilson'))

# Use .loc and the filter to select for rides
print("Riders during weekdays in July",ridership_cal_stations.loc[filter_criteria, 'rides'].sum())
# Out:
#   station_id  year  month  day  rides        day_type
# 0      40010  2019      1    1    576  Sunday/Holiday
# 1      40080  2019      1    1   1839  Sunday/Holiday
# 2      40770  2019      1    1   2724  Sunday/Holiday
#   station_id  year  month  day  rides        day_type        station_name  \
# 0      40010  2019      1    1    576  Sunday/Holiday  Austin-Forest Park
# 1      40010  2019      1    2   1457         Weekday  Austin-Forest Park
# 2      40010  2019      1    3   1543         Weekday  Austin-Forest Park
#
#                   location
# 0  (41.870851, -87.776812)
# 1  (41.870851, -87.776812)
# 2  (41.870851, -87.776812)
# Riders during weekdays in July 140005

# %% [markdown]
# we merged three DataFrames together, including merging two tables on multiple columns. Once the tables were merged, we filtered and selected just like any other DataFrame. Finally, you found out that the `Wilson` station had `140,005` riders during `weekdays` in `July`.

# %% [markdown]
# ### **Three Table Merge**

# %%
licenses = pd.read_pickle("/content/licenses.p")
zip_demo = pd.read_pickle("/content/zip_demo.p")
wards = pd.read_pickle("/content/ward.p")

display(licenses.head(1), zip_demo.head(1), wards.head(1))
# Out:
#   account ward  aid              business          address    zip
# 0  307071    3  743  REGGIE'S BAR & GRILL  2105 S STATE ST  60616
#      zip  income
# 0  60630   70122
#   ward            alderman                    address    zip
# 0    1  Proco "Joe" Moreno  2058 NORTH WESTERN AVENUE  60647

# %%
# Merge licenses and zip_demo, on zip; and merge the wards on ward
licenses_zip_ward = licenses.merge(zip_demo, on='zip').merge(wards, on='ward')
display(licenses_zip_ward.head(2))

# Print the results by alderman and show median income
print(licenses_zip_ward.groupby('alderman').agg({'income': np.median}))
# Out:
#   account ward  aid              business            address_x  zip_x  income  \
# 0  307071    3  743  REGGIE'S BAR & GRILL      2105 S STATE ST  60616   46340
# 1   11280    3  763             PRIME WAY  2251 S STATE ST 1ST  60616   46340
#
#      alderman                address_y  zip_y
# 0  Pat Dowell  5046 SOUTH STATE STREET  60609
# 1  Pat Dowell  5046 SOUTH STATE STREET  60609
#                              income
# alderman
# Ameya Pawar                 66246.0
# Anthony A. Beale            38206.0
# Anthony V. Napolitano       82226.0
# Ariel E. Reyboras           41307.0
# Brendan Reilly             110215.0
# Brian Hopkins               87143.0
# Carlos Ramirez-Rosa         66246.0
# Carrie M. Austin            38206.0
# Chris Taliaferro            55566.0
# Daniel "Danny" Solis        41226.0
# David H. Moore              33304.0
# Deborah Mell                66246.0
# Debra L. Silverstein        50554.0
# Derrick G. Curtis           65770.0
# ...

# %% [markdown]
# Only a few aldermen represent businesses in areas where the median income is greater than `$62,000`, which is the median income for the state of Illinois.

# %% [markdown]
# ### **One-to-many merge with multiple tables**
#
# In this exercise, assume that you are looking to start a business in the city of Chicago. Your perfect idea is to start a company that uses goats to mow the lawn for other businesses. However, you have to choose a location in the city to put your goat farm. You need a location with a great deal of space and relatively few businesses and people around to avoid complaints about the smell. You will need to merge three tables to help you choose your location. The land_use table has info on the percentage of vacant land by city ward. The census table has population by ward, and the licenses table lists businesses by ward.
#
# - `land_use`,
# - `census`, and
# - `licenses` tables

# %%
land_use = pd.read_pickle("/content/land_use.p")
census = pd.read_pickle("/content/census.p")
licenses = pd.read_pickle("/content/licenses.p")

display(land_use.head(1), census.head(1), licenses.head(1))
# Out:
#   ward  residential  commercial  industrial  vacant  other
# 0    1           41           9           2       2     46
#   ward  pop_2000  pop_2010 change                      address    zip
# 0    1     52951     56149     6%  2765 WEST SAINT MARY STREET  60647
#   account ward  aid              business          address    zip
# 0  307071    3  743  REGGIE'S BAR & GRILL  2105 S STATE ST  60616

# %%
# Merge land_use and census and merge result with licenses including suffixes
land_cen_lic = land_use.merge(census, on='ward').merge(licenses, on='ward', suffixes=('_cen', '_lic'))
display(land_cen_lic.head(2))
# Out:
#   ward  residential  commercial  industrial  vacant  other  pop_2000  \
# 0    1           41           9           2       2     46     52951
# 1    1           41           9           2       2     46     52951
#
#    pop_2010 change                  address_cen zip_cen account  aid  \
# 0     56149     6%  2765 WEST SAINT MARY STREET   60647   12024  NaN
# 1     56149     6%  2765 WEST SAINT MARY STREET   60647   14446  743
#
#               business             address_lic zip_lic
# 0  DIGILOG ELECTRONICS      1038 N ASHLAND AVE   60622
# 1     EMPTY BOTTLE INC  1035 N WESTERN AVE 1ST   60622

# %%
# Group by ward, pop_2010, and vacant, then count the # of accounts
pop_vac_lic = land_cen_lic.groupby(['ward', 'pop_2010', 'vacant'], as_index=False).agg({'account': 'count'})
pop_vac_lic.head(2)
# Out:
#   ward  pop_2010  vacant  account
# 0    1     56149       2      253
# 1   10     51535      14      130

# %%
# Merge land_use and census and merge result with licenses including suffixes
land_cen_lic = land_use.merge(census, on='ward').merge(licenses, on='ward', suffixes=('_cen', '_lic'))
land_cen_lic.head(2)
# Out:
#   ward  residential  commercial  industrial  vacant  other  pop_2000  \
# 0    1           41           9           2       2     46     52951
# 1    1           41           9           2       2     46     52951
#
#    pop_2010 change                  address_cen zip_cen account  aid  \
# 0     56149     6%  2765 WEST SAINT MARY STREET   60647   12024  NaN
# 1     56149     6%  2765 WEST SAINT MARY STREET   60647   14446  743
#
#               business             address_lic zip_lic
# 0  DIGILOG ELECTRONICS      1038 N ASHLAND AVE   60622
# 1     EMPTY BOTTLE INC  1035 N WESTERN AVE 1ST   60622

# %%
# Group by ward, pop_2010, and vacant, then count the # of accounts
pop_vac_lic = land_cen_lic.groupby(['ward', 'pop_2010', 'vacant'], as_index=False).agg({'account': 'count'})

# Sort pop_vac_lic and print the results
sorted_pop_vac_lic = pop_vac_lic.sort_values(['vacant', 'account', 'pop_2010'], ascending=[False, True, True])

# Print the top few rows of sorted_pop_vac_lic
display(sorted_pop_vac_lic.head(2))
# Out:
#    ward  pop_2010  vacant  account
# 47    7     51581      19       80
# 12   20     52372      15      123

# %% [markdown]
# # 🟥**2. Merging Tables With Different Join Types**

# %% [markdown]
# ### **Counting missing rows with left join**

# %%
movies = pd.read_pickle("/content/movies.p")
financials = pd.read_pickle("/content/financials.p")

display(movies.head(1), financials.head(1))
# Out:
#     id         title  popularity release_date
# 0  257  Oliver Twist   20.415572   2005-09-23
#       id     budget       revenue
# 0  19995  237000000  2.787965e+09

# %%
# Merge movies and financials with a left join
movies_financials = movies.merge(financials, on='id', how='left')
display(movies_financials.head(2))

# Count the number of rows in the budget column that are missing
print("number_of_missing_fin:", movies_financials['budget'].isnull().sum())
# Out:
#       id                 title  popularity release_date      budget  \
# 0    257          Oliver Twist   20.415572   2005-09-23  50000000.0
# 1  14290  Better Luck Tomorrow    3.877036   2002-01-12         NaN
#
#       revenue
# 0  42093706.0
# 1         NaN
# number_of_missing_fin: 1574

# %% [markdown]
# ### **Enriching a dataset**

# %% [markdown]
# - `left` JOIN is used to get all records from the left data frame and only matching records from the right data frame.
#
# - `inner` JOIN is used to get only matching records from both data frames.

# %%
import pandas as pd

# employees DataFrame
employees = pd.DataFrame({
    'emp_id': [1, 2, 3, 4, 5],
    'name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'dept_id': [1, 2, 2, 3, 4]
})

# departments DataFrame
departments = pd.DataFrame({
    'dept_id': [1, 2, 3],
    'dept_name': ['HR', 'IT', 'Finance']
})

# perform a LEFT JOIN
left_join_df = pd.merge(employees, departments, on='dept_id', how='left')
display(left_join_df)

print('-'*40)
# perform an INNER JOIN
inner_join_df = pd.merge(employees, departments, on='dept_id', how='inner')
display(inner_join_df)
# Out:
#    emp_id     name  dept_id dept_name
# 0       1    Alice        1        HR
# 1       2      Bob        2        IT
# 2       3  Charlie        2        IT
# 3       4    David        3   Finance
# 4       5      Eve        4       NaN
# ----------------------------------------
#    emp_id     name  dept_id dept_name
# 0       1    Alice        1        HR
# 1       2      Bob        2        IT
# 2       3  Charlie        2        IT
# 3       4    David        3   Finance

# %%
toy_story = movies[movies['title'].isin(['Toy Story', 'Toy Story 2', 'Toy Story 3'])]
taglines = pd.read_pickle("/content/taglines.p")

display(toy_story.head(1), taglines.head(1))
# Out:
#         id        title  popularity release_date
# 103  10193  Toy Story 3   59.995418   2010-06-16
#       id                      tagline
# 0  19995  Enter the World of Pandora.

# %%
# Merge the toy_story and taglines tables with a left join
toystory_tag = toy_story.merge(taglines, on='id', how='left')

# Print the rows and shape of toystory_tag
print(toystory_tag)
print(toystory_tag.shape)
# Out:
#       id        title  popularity release_date                   tagline
# 0  10193  Toy Story 3   59.995418   2010-06-16  No toy gets left behind.
# 1    863  Toy Story 2   73.575118   1999-10-30        The toys are back!
# 2    862    Toy Story   73.640445   1995-10-30                       NaN
# (3, 5)

# %%
# Merge the toy_story and taglines tables with a inner join
toystory_tag = toy_story.merge(taglines, on='id', how='inner')

# Print the rows and shape of toystory_tag
print(toystory_tag)
print(toystory_tag.shape)
# Out:
#       id        title  popularity release_date                   tagline
# 0  10193  Toy Story 3   59.995418   2010-06-16  No toy gets left behind.
# 1    863  Toy Story 2   73.575118   1999-10-30        The toys are back!
# (2, 5)

# %% [markdown]
# ### **Right join to find unique movies**

# %%
movie_to_genres = pd.read_pickle("/content/movie_to_genres.p")
genre = movie_to_genres.rename(columns={'movie_id':'id'})


movies_genre = movies.merge(genre, on='id', how='inner')
scifi_movies = movies_genre[movies_genre['genre'] == 'Science Fiction']
action_movies = movies_genre[movies_genre['genre'] == 'Action']

display(scifi_movies.head(2), action_movies.head(2))
# Out:
#        id                         title  popularity release_date  \
# 9   49529                   John Carter   43.926995   2012-03-07
# 17  18841  The Lost Skeleton of Cadavra    1.680525   2001-09-12
#
#               genre
# 9   Science Fiction
# 17  Science Fiction
#        id              title  popularity release_date   genre
# 11  49529        John Carter   43.926995   2012-03-07  Action
# 20  76757  Jupiter Ascending   85.369080   2015-02-04  Action

# %%
action_scifi = action_movies.merge(scifi_movies, on='id', how='right', suffixes=('_act', '_sci'))
action_scifi.head(2)
# Out:
#       id    title_act  popularity_act release_date_act genre_act  \
# 0  49529  John Carter       43.926995       2012-03-07    Action
# 1  18841          NaN             NaN              NaN       NaN
#
#                       title_sci  popularity_sci release_date_sci  \
# 0                   John Carter       43.926995       2012-03-07
# 1  The Lost Skeleton of Cadavra        1.680525       2001-09-12
#
#          genre_sci
# 0  Science Fiction
# 1  Science Fiction

# %%
import pandas as pd

# Create two sample dataframes with different column names
df1 = pd.DataFrame({'key1': ['A', 'B', 'C', 'D'], 'value1': [1, 2, 3, 4]})
df2 = pd.DataFrame({'key2': ['B', 'D', 'E', 'F'], 'value2': [5, 6, 7, 8]})

# Merge the dataframes based on the "key1" and "key2" columns using inner join
merged_df = pd.merge(df1, df2, how='inner', left_on='key1', right_on='key2')

print(merged_df)
# Out:
#   key1  value1 key2  value2
# 0    B       2    B       5
# 1    D       4    D       6

# %% [markdown]
# ### **Popular genres with right join**

# %%
# Use right join to merge the movie_to_genres and movies tables
genres_movies = movie_to_genres.merge(movies, how='right',
                                      left_on='movie_id',
                                      right_on='id')

# Count the number of genres
genre_count = genres_movies.groupby('genre').agg({'id': 'count'})

# Plot a bar chart of the genre_count
genre_count.plot(kind='bar')
plt.show()

# %% [markdown]
# ### **Using outer join to select actors**
# One cool aspect of using an `outer` join is that, because it returns all rows from both `merged` tables and `null` where they `do not match`, you can use it to find rows that do not have a match in the other table.
#
# To try for yourself, you have been given two tables with a list of actors from two popular movies: `Iron Man 1` and `Iron Man 2`. Most of the actors played in both movies.
#
# >**Use an outer join to find actors who did not act in both movies.**
#
# ![outer join](https://assets.datacamp.com/production/repositories/5486/datasets/c5d02ebba511e90ae132f89ff091e6729c040bd2/noJoin.png)

# %%
movies = pd.read_pickle("/content/movies.p")
movies = movies.rename(columns={'id':'movie_id'})

cast = pd.read_pickle("/content/casts.p")
movies_cast = cast.merge(movies, on='movie_id', how='outer')

# movies_cast[movies_cast['title'].isin(['Iron Man', 'Iron Man 2', 'Iron Man 3'])]
iron_1_actors = movies_cast[movies_cast['title'].isin(['Iron Man'])]
iron_2_actors = movies_cast[movies_cast['title'].isin(['Iron Man 2'])]

# Merge iron_1_actors to iron_2_actors on id with outer join using suffixes
iron_1_and_2 = iron_1_actors.merge(iron_2_actors,
                                   on='id',
                                   how='outer',
                                   suffixes=('_1', '_2'))

# Create an index that returns true if name_1 or name_2 are null
m = ((iron_1_and_2['name_1'].isnull()) | (iron_1_and_2['name_2'].isnull()))

# Print the first few rows of iron_1_and_2
print(iron_1_and_2[m].head())
# Out:
#    movie_id_1  cast_id_1                                   character_1  \
# 0      1726.0        9.0                                        Yinsen
# 2      1726.0       11.0                   Obadiah Stane / Iron Monger
# 3      1726.0       12.0  Lt. Col. James "Rhodey" Rhodes / War Machine
# 5      1726.0       18.0                                          Raza
# 8      1726.0       23.0                                    Abu Bakaar
#
#    gender_1        id           name_1   title_1  popularity_1 release_date_1  \
# 0       2.0   17857.0       Shaun Toub  Iron Man    120.725053     2008-04-30
# 2       2.0    1229.0     Jeff Bridges  Iron Man    120.725053     2008-04-30
# 3       2.0   18288.0  Terrence Howard  Iron Man    120.725053     2008-04-30
# 5       2.0   57452.0      Faran Tahir  Iron Man    120.725053     2008-04-30
# 8       2.0  173810.0    Sayed Badreya  Iron Man    120.725053     2008-04-30
#
# ...

# %% [markdown]
# ### **Self join**
#
# Merging a table to itself can be useful when you want to compare values in a column to other values in the same column.
#
# In this exercise, you will practice this by creating a table that for each `movie` will list the `movie director` and a member of the `crew` on one row. You have been given a table called `crews`, which has columns `id`, `job`, and `name`.
#
# First, merge the table to itself using the `movie ID`. This merge will give you a larger table where for each movie, every job is matched against each other. Then select only those rows with a director in the left table, and avoid having a row where the director's job is listed in both the left and right tables. This filtering will remove job combinations that aren't with the director.

# %%
crews = pd.read_pickle("/content/crews.p")

# %%
# Merge the crews table to itself
crews_self_merged = crews.merge(crews, on='id', how='inner', suffixes=('_dir', '_crew'))

# Create a boolean index to select the appropriate rows
boolean_filter = ((crews_self_merged['job_dir'] == 'Director') & (crews_self_merged['job_crew'] != 'Director'))
direct_crews = crews_self_merged[boolean_filter]

# Print the first few rows of direct_crews
display(direct_crews.head())
# Out:
#         id department_dir   job_dir       name_dir department_crew  \
# 156  19995      Directing  Director  James Cameron         Editing
# 157  19995      Directing  Director  James Cameron           Sound
# 158  19995      Directing  Director  James Cameron      Production
# 160  19995      Directing  Director  James Cameron         Writing
# 161  19995      Directing  Director  James Cameron             Art
#
#            job_crew          name_crew
# 156          Editor  Stephen E. Rivkin
# 157  Sound Designer  Christopher Boyes
# 158         Casting          Mali Finn
# 160          Writer      James Cameron
# 161    Set Designer    Richard F. Mays

# %% [markdown]
# By merging the table to itself, you compared the value of the `__director__` from the jobs column to other values from the jobs column. With the output, you can quickly see different movie directors and the people they worked with in the same movie.

# %% [markdown]
# ### **Index merge for movie ratings**

# %%
movies = pd.read_pickle("/content/movies.p")
ratings = pd.read_pickle("/content/ratings.p")

# Merge to the movies table the ratings table on the index
movies_ratings = movies.merge(ratings, on='id', how='left')

# Print the first few rows of movies_ratings
display(movies_ratings.head())
# Out:
#       id                 title  popularity release_date  vote_average  \
# 0    257          Oliver Twist   20.415572   2005-09-23           6.7
# 1  14290  Better Luck Tomorrow    3.877036   2002-01-12           6.5
# 2  38365             Grown Ups   38.864027   2010-06-24           6.0
# 3   9672              Infamous    3.680896   2006-11-16           6.4
# 4  12819       Alpha and Omega   12.300789   2010-09-17           5.3
#
#    vote_count
# 0       274.0
# 1        27.0
# 2      1705.0
# 3        60.0
# 4       124.0

# %% [markdown]
# ### **Do sequels earn more?**

# %%
sequels = pd.read_pickle("/content/sequels.p")
display(sequels.head(2))

financials = pd.read_pickle("/content/financials.p")
display(financials.head(2))
# Out:
#       id      title  sequel
# 0  19995     Avatar    <NA>
# 1    862  Toy Story     863
#       id     budget       revenue
# 0  19995  237000000  2.787965e+09
# 1    285  300000000  9.610000e+08

# %%
# Merge sequels and financials on index id
sequels_fin = sequels.merge(financials, on='id', how='left')
sequels_fin = sequels_fin.dropna(subset=['sequel'])

# Self merge with suffixes as inner join with left on sequel and right on id
orig_seq = sequels_fin.merge(sequels_fin, how='inner', left_on='sequel',
                             right_on='id', right_index=True,
                             suffixes=('_org', '_seq'))

# Add calculation to subtract revenue_org from revenue_seq
orig_seq['diff'] = orig_seq['revenue_seq'] - orig_seq['revenue_org']

# Select the title_org, title_seq, and diff
titles_diff = orig_seq[['title_org', 'title_seq', 'diff']]

# Print the first rows of the sorted titles_diff
display(titles_diff.sort_values('diff', ascending=False).head())
# Out:
#                                               title_org  \
# 1256                Star Trek III: The Search for Spock
# 293                Indiana Jones and the Temple of Doom
# 229                                       Batman Begins
# 44    The Lord of the Rings: The Fellowship of the Ring
#
#                            title_seq         diff
# 1256                      The Matrix  376517383.0
# 293                     Man of Steel  329845518.0
# 229   Rise of the Planet of the Apes  108641512.0
# 44                    Monsters, Inc. -308552108.0

# %% [markdown]
# # 🟥**3. Advanced Merging and Concatenating**

# %% [markdown]
# ### **Semi-join**
# Steps to perform a semi-join:
#
# It returns only the rows from the left table that have a match in the right table.
#
# - Merge the `left` and `right` tables on `key` column using an `inner` join.
# - Search if `key` column in the `left` table is in the merged tables using `.isin()` method creating Boolean Series
# - Subset the rows of the `left` table.

# %%
# Create two dataframes
df1 = pd.DataFrame({'key': [1, 2, 3], 'name': ['Alice', 'Bob', 'Charlie']})
df2 = pd.DataFrame({'key': [2, 3, 4], 'age': [25, 30, 35]})

# Merge the two dataframes on the 'id' column
merged_df = df1.merge(df2[['key']], on='key', how='inner', indicator=True)
display(merged_df)

# Get the names of the people with an age
with_age_df = merged_df[['key', 'name']]
print("The following people have an age:\n", with_age_df)
# Out:
#    key     name _merge
# 0    2      Bob   both
# 1    3  Charlie   both
# The following people have an age:
#     key     name
# 0    2      Bob
# 1    3  Charlie

# %%
# Create example DataFrames
df1 = pd.DataFrame({'id': [1, 2, 3, 4, 5], 'category': ['A', 'B', 'B', 'C', 'C']})
df2 = pd.DataFrame({'id': [2, 4], 'value': [10, 20]})

# Use isin() to subset df1 to rows with id in df2
df1_subset = df1[df1['id'].isin(df2['id'])]

# Group df1_subset by category and count the id rows
count_by_category = df1_subset.groupby('category', as_index=False).agg({'id': 'count'})

# Merge the resulting DataFrame with a third DataFrame on the category column
df3 = pd.DataFrame({'category': ['A', 'B', 'C'],
                    'name': ['apple', 'banana', 'carrot']})

result = count_by_category.merge(df3, on='category')

print(result)
# Out:
#   category  id    name
# 0        B   1  banana
# 1        C   1  carrot

# %% [markdown]
# ### **Anti join**
# This type of join that returns all the rows from the left table that don't have a match in the right table.

# %%
# Create two dataframes
df1 = pd.DataFrame({'id': [1, 2, 3], 'name': ['Alice', 'Bob', 'Charlie']})
df2 = pd.DataFrame({'id': [2, 3, 4], 'age': [25, 30, 35]})

# Merge the two dataframes on the 'id' column
merged_df = df1.merge(df2, on='id', how='left', indicator=True)
display(merged_df)

# Select the rows where _merge is left_only
left_only_df = merged_df.loc[merged_df['_merge'] == 'left_only', :]

# Get the names of the people who don't have an age
display(left_only_df['name'])
# Out:
#    id     name   age     _merge
# 0   1    Alice   NaN  left_only
# 1   2      Bob  25.0       both
# 2   3  Charlie  30.0       both
# 0    Alice
# Name: name, dtype: object

# %% [markdown]
# ou performed an anti join by first merging the tables with a left join, selecting the ID of those employees who did not support a top customer, and then subsetting the original employee's table. From that, we can see that there are five employees not supporting top customers. Anti joins are a powerful tool to filter a main table

# %% [markdown]
# ### **Concatenation basics**

# %%
# Dummy data with non-numeric values
data1 = pd.DataFrame({'Name': ['John', 'Alice', 'Bob'],
                      'Age': [30, 25, 27],
                      'Gender': ['Male', 'Female', 'Male'],
                      'Occupation': ['Doctor', 'Engineer', 'Teacher']})

data2 = pd.DataFrame({'Name': ['Mary', 'Jane', 'Liam'],
                      'Age': [35, 29, 31],
                      'Gender': ['Female', 'Female', 'Male'],
                      'Occupation': ['Doctor', 'Nurse', 'Engineer']})

data3 = pd.DataFrame({'Name': ['Sophie', 'David', 'Eric'],
                      'Age': [24, 32, 28],
                      'Gender': ['Female', 'Male', 'Male'],
                      'Occupation': ['Teacher', 'Doctor', 'Lawyer']})

# Concatenate the dataframes
concatenated_data = pd.concat([data1, data2, data3], sort=True)
print("concatenated_data:\n", concatenated_data)

# Concatenate the dataframes with reset index
concatenated_data_reset_index = pd.concat([data1, data2, data3], ignore_index=True, sort=True)
print("\nconcatenated_data_reset_index:\n", concatenated_data_reset_index)

# Concatenate the dataframes and keep only common columns
concatenated_data_common_columns = pd.concat([data1, data2, data3], join='inner', sort=True)
print("\nconcatenated_data_common_columns:\n", concatenated_data_common_columns)
# Out:
# concatenated_data:
#     Age  Gender    Name Occupation
# 0   30    Male    John     Doctor
# 1   25  Female   Alice   Engineer
# 2   27    Male     Bob    Teacher
# 0   35  Female    Mary     Doctor
# 1   29  Female    Jane      Nurse
# 2   31    Male    Liam   Engineer
# 0   24  Female  Sophie    Teacher
# 1   32    Male   David     Doctor
# 2   28    Male    Eric     Lawyer
#
# concatenated_data_reset_index:
#     Age  Gender    Name Occupation
# 0   30    Male    John     Doctor
# 1   25  Female   Alice   Engineer
# 2   27    Male     Bob    Teacher
# 3   35  Female    Mary     Doctor
# 4   29  Female    Jane      Nurse
# 5   31    Male    Liam   Engineer
# 6   24  Female  Sophie    Teacher
# 7   32    Male   David     Doctor
# 8   28    Male    Eric     Lawyer
#
# concatenated_data_common_columns:
#     Age  Gender    Name Occupation
# 0   30    Male    John     Doctor
# 1   25  Female   Alice   Engineer
# 2   27    Male     Bob    Teacher
# 0   35  Female    Mary     Doctor
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Create some dummy data
sales_jan = pd.DataFrame({
    'date': pd.date_range(start='2022-01-01', end='2022-01-31'),
    'sales': np.random.randint(100, 1000, 31)
    })

sales_feb = pd.DataFrame({
    'date': pd.date_range(start='2022-02-01', end='2022-02-28'),
    'sales': np.random.randint(100, 1000, 28)
    })

sales_mar = pd.DataFrame({
    'date': pd.date_range(start='2022-03-01', end='2022-03-31'),
    'sales': np.random.randint(100, 1000, 31)
    })

# Concatenate the sales data and add keys
sales_q1 = pd.concat([sales_jan, sales_feb, sales_mar],
                     ignore_index=True,
                     keys=['Q1-Jan', 'Q1-Feb', 'Q1-Mar'])

display(sales_q1.head(10))

# Group the sales data by month and calculate the sum
sales_by_month = sales_q1.groupby(pd.Grouper(key='date', freq='M')).agg({'sales': 'sum'})

# Format the x-axis labels to display only the month and year
sales_by_month.index = sales_by_month.index.strftime('%b %Y')

# Bar plot of sales_by_month
sales_by_month.plot(kind='bar')
plt.show()
# Out:
#         date  sales
# 0 2022-01-01    679
# 1 2022-01-02    341
# 2 2022-01-03    686
# 3 2022-01-04    733
# 4 2022-01-05    871
# 5 2022-01-06    675
# 6 2022-01-07    814
# 7 2022-01-08    860
# 8 2022-01-09    486
# 9 2022-01-10    136

# %% [markdown]
#  ### **Many to One**
#
# We `many_to_one` without an error, If there is a `duplicate` key in the left.

# %%
# Define the artists and albums data
artists = pd.DataFrame({
    'artid': [1, 2, 3, 4, 5],
    'name': ['AC/DC', 'Accept', 'Aerosmith', 'Bon Jovi', 'Guns N\' Roses']
})

albums = pd.DataFrame({
    'aid': [1, 2, 3, 4, 5, 6, 7, 8],
    'artid': [1, 1, 2, 2, 3, 4, 4, 5],
    'title': ['For Those About To Rock We Salute You',
              'Let There Be Rock',
              'Balls to the Wall',
              'Restless and Wild',
              'Big Ones',
              'New Jersey',
              'Slippery When Wet',
              'Appetite for Destruction']
})


# Merge the two DataFrames on the artid column
merged = artists.merge(albums, on='artid')

# Print the first 5 rows of the merged DataFrame
display(merged.head())
# Out:
#    artid       name  aid                                  title
# 0      1      AC/DC    1  For Those About To Rock We Salute You
# 1      1      AC/DC    2                      Let There Be Rock
# 2      2     Accept    3                      Balls to the Wall
# 3      2     Accept    4                      Restless and Wild
# 4      3  Aerosmith    5                               Big Ones

# %% [markdown]
# Each row in the artists DataFrame corresponds to one unique artist, but each artist can have multiple albums. Therefore, the merge operation will return a DataFrame that has multiple rows for each artist (one for each album), resulting in a one-to-many relationship.

# %% [markdown]
# ### **Concatenate and merge to find common**

# %%
import pandas as pd

# Create df1 with fruits and their corresponding colors
df1 = pd.DataFrame({
    'fruit': ['apple', 'banana', 'orange', 'pear', 'kiwi'],
    'color': ['red', 'yellow', 'orange', 'green', 'brown']
})

# Create df2 with fruits and their corresponding prices
df2 = pd.DataFrame({
    'fruit': ['apple', 'banana', 'orange', 'watermelon', 'grape'],
    'price': [0.50, 0.25, 0.30, 1.00, 0.05]
})

# Concatenate the dataframes vertically
df = pd.concat([df1, df2], ignore_index=True)

# Merge the dataframes on the 'fruit' column
merged = df1.merge(df2, on='fruit')

# Filter df1 rows where 'fruit' is in merged
popular_fruit = df1[df1['fruit'].isin(merged['fruit'])]

# Print popular fruit
display(popular_fruit)
# Out:
#     fruit   color
# 0   apple     red
# 1  banana  yellow
# 2  orange  orange

# %% [markdown]
# # 🟥**4. Merging Ordered and Time-Series Dat**a

# %% [markdown]
# ### **Correlation between GDP and S&P500**

# %%
display("df_snp500", df_snp500.head(2))
display("df_worldbank_gdp", df_worldbank_gdp.head(2))
display("df_worldbank_pop", df_worldbank_pop.head(2))
# Out:
# 'df_snp500'
#    Date  Returns
# 0  2008   -38.49
# 1  2009    23.45
# 'df_worldbank_gdp'
#   Country Name Country Code     Indicator Name  Year           GDP
# 0        China          CHN  GDP (current US$)  2010  6.087160e+12
# 1      Germany          DEU  GDP (current US$)  2010  3.417090e+12
# 'df_worldbank_pop'
#   Country Name Country Code     Indicator Name  Year         Pop
# 0        Aruba          ABW  Population, total  2010    101669.0
# 1  Afghanistan          AFG  Population, total  2010  29185507.0

# %%
data = {'country code': ['USA', 'USA', 'USA', 'USA', 'USA', 'USA', 'USA', 'USA', 'USA', 'USA'],
        'year': [2010, 2011, 2012, 2012, 2013, 2014, 2015, 2016, 2017, 2018],
        'gdp': [1.499e+13, 1.554e+13, 1.620e+13, 1.620e+13, 1.678e+13, 1.752e+13, 1.822e+13, 1.871e+13, 1.949e+13, 2.049e+13]}

gdp = pd.DataFrame(data, index=[3, 7, 11, 15, 19, 23, 27, 31, 35, 39])
display(gdp.head(2))
# Out:
#   country code  year           gdp
# 3          USA  2010  1.499000e+13
# 7          USA  2011  1.554000e+13

# %%
# Use merge_ordered() to merge gdp and snp500, interpolate missing value
gdp_snp500 = pd.merge_ordered(gdp, df_snp500, left_on='year', right_on='Date',
                             how='left',  fill_method='ffill')

display(gdp_snp500)
# Subset the gdp and returns columns
gdp_returns = gdp_snp500[['gdp', 'Returns']]

# Print gdp_returns correlation
print(gdp_returns.corr())
# Out:
#   country code  year           gdp  Date  Returns
# 0          USA  2010  1.499000e+13  2010    12.78
# 1          USA  2011  1.554000e+13  2011     0.00
# 2          USA  2012  1.620000e+13  2012    13.41
# 3          USA  2012  1.620000e+13  2012    13.41
# 4          USA  2013  1.678000e+13  2013    29.60
# 5          USA  2014  1.752000e+13  2014    11.39
# 6          USA  2015  1.822000e+13  2015    -0.73
# 7          USA  2016  1.871000e+13  2016     9.54
# 8          USA  2017  1.949000e+13  2017    19.42
# 9          USA  2018  2.049000e+13  2017    19.42
#               gdp   Returns
# gdp      1.000000  0.211734
# Returns  0.211734  1.000000

# %% [markdown]
# we can now see the different aspects of `merge_ordered()` and how you might use it on data that can be ordered. By using this function, you were able to `fill` in the missing `data` from `2019`. Finally, the `correlation` of `0.21` between the `GDP` and `S&P500` is `low` to moderate at `best`. You may want to find another predictor if you plan to play in the stock market.

# %% [markdown]
# ### **Phillips curve using `merge_ordered()`**

# %%
# create a DataFrame from the provided data
inflation_dict = {
    'date' : ['2014-01-01', '2014-02-01', '2014-03-01', '2014-04-01', '2014-05-01', '2014-06-01', '2014-07-01', '2014-08-01', '2014-09-01', '2014-10-01', '2014-11-01', '2014-12-01', '2015-01-01', '2015-02-01', '2015-03-01', '2015-04-01', '2015-05-01', '2015-06-01', '2015-07-01', '2015-08-01', '2015-09-01', '2015-10-01', '2015-11-01', '2015-12-01', '2016-01-01', '2016-02-01', '2016-03-01', '2016-04-01', '2016-05-01', '2016-06-01', '2016-07-01', '2016-08-01', '2016-09-01', '2016-10-01', '2016-11-01', '2016-12-01', '2017-01-01', '2017-02-01', '2017-03-01', '2017-04-01', '2017-05-01', '2017-06-01', '2017-07-01', '2017-08-01', '2017-09-01', '2017-10-01', '2017-11-01', '2017-12-01', '2018-01-01', '2018-02-01', '2018-03-01', '2018-04-01', '2018-05-01', '2018-06-01', '2018-07-01', '2018-08-01', '2018-09-01', '2018-10-01', '2018-11-01', '2018-12-01'],
    'cpi' : [235.28799999999998, 235.547, 236.028, 236.468, 236.918, 237.231, 237.498, 237.46, 237.477, 237.43, 236.983, 236.252, 234.718, 235.236, 236.005, 236.15599999999998, 236.97400000000002, 237.68400000000003, 238.053, 238.028, 237.50599999999997, 237.78099999999998, 238.016, 237.817, 237.833, 237.46900000000002, 238.03799999999998, 238.827, 239.46400000000003, 240.167, 240.15, 240.602, 241.051, 241.69099999999997, 242.02900000000002, 242.77200000000002, 243.78, 243.96099999999998, 243.74900000000002, 244.051, 243.96200000000002, 244.18200000000002, 244.39, 245.297, 246.418, 246.58700000000002, 247.332, 247.90099999999998, 248.88400000000001, 249.36900000000003, 249.498, 249.956, 250.646, 251.13400000000001, 251.597, 251.87900000000002, 252.01, 252.794, 252.76, 252.72299999999998],
    'seriesid' : ['CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0', 'CUSR0000SA0'],
    'data_type' : ['SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX', 'SEASONALLY ADJUSTED INDEX']
}

unemployment_dict = {
    'date' : ['2013-06-01', '2014-01-01', '2014-06-01', '2015-01-01', '2015-06-01', '2016-01-01', '2016-06-01', '2017-01-01', '2017-06-01', '2018-01-01', '2018-06-01', '2019-01-01', '2019-06-01', '2020-01-01'],
    'unemployment_rate' : [7.5, 6.7, 6.1, 5.6, 5.3, 5.0, 4.9, 4.7, 4.3, 4.1, 4.0, 3.9, 3.7, 3.5]
    
}

inflation = pd.DataFrame(inflation_dict)
unemployment = pd.DataFrame(unemployment_dict)

# %%
# Use merge_ordered() to merge inflation, unemployment with inner join
inflation_unemploy = pd.merge_ordered(inflation, unemployment, on='date', how='inner')

# Print inflation_unemploy
display(inflation_unemploy)

# Plot a scatter plot of unemployment_rate vs cpi of inflation_unemploy
inflation_unemploy.plot(kind='scatter', x='unemployment_rate', y='cpi')
plt.show()
# Out:
#          date      cpi     seriesid                  data_type  \
# 0  2014-01-01  235.288  CUSR0000SA0  SEASONALLY ADJUSTED INDEX
# 1  2014-06-01  237.231  CUSR0000SA0  SEASONALLY ADJUSTED INDEX
# 2  2015-01-01  234.718  CUSR0000SA0  SEASONALLY ADJUSTED INDEX
# 3  2015-06-01  237.684  CUSR0000SA0  SEASONALLY ADJUSTED INDEX
# 4  2016-01-01  237.833  CUSR0000SA0  SEASONALLY ADJUSTED INDEX
# 5  2016-06-01  240.167  CUSR0000SA0  SEASONALLY ADJUSTED INDEX
# 6  2017-01-01  243.780  CUSR0000SA0  SEASONALLY ADJUSTED INDEX
# 7  2017-06-01  244.182  CUSR0000SA0  SEASONALLY ADJUSTED INDEX
# 8  2018-01-01  248.884  CUSR0000SA0  SEASONALLY ADJUSTED INDEX
# 9  2018-06-01  251.134  CUSR0000SA0  SEASONALLY ADJUSTED INDEX
#
#    unemployment_rate
# 0                6.7
# 1                6.1
# 2                5.6
# 3                5.3
# 4                5.0
# 5                4.9
# 6                4.7
# 7                4.3
# 8                4.1
# 9                4.0

# %% [markdown]
# **Phillips curve:** There are critics of the curve, but what is more important in this example is that you were able to use entries where you had entries in both tables by using an inner join. You might ask why not use the default outer join and use forward fill to fill to estimate the missing variables. You might choose differently. In this case, instead of showing an estimated unemployment rate (which is a continually changing measure) for five periods, that data was dropped from the plot.

# %% [markdown]
# ### **`merge_ordered()` caution, multiple columns**
#
# When using `merge_ordered()` to merge on multiple columns, the order is important when you combine it with the forward fill feature.
#
# The function sorts the merge on columns in the order provided. In this exercise, we will merge `GDP` and `population` data from the World Bank for the Australia and Sweden, reversing the order of the merge on columns. The frequency of the series are different, the GDP values are quarterly, and the population is yearly. Use the forward fill feature to fill in the missing data. Depending on the order provided, the fill forward will use unintended data to fill in the missing values.

# %%
pop_dict = {
    'date' : ['1990-01-01 00:00:00', '1991-01-01 00:00:00', '1992-01-01 00:00:00', '1993-01-01 00:00:00', '1990-01-01 00:00:00', '1991-01-01 00:00:00', '1992-01-01 00:00:00', '1993-01-01 00:00:00'],
    'country' : ['Australia', 'Australia', 'Australia', 'Australia', 'Sweden', 'Sweden', 'Sweden', 'Sweden'],
    'pop' : [17065100, 17284000, 17495000, 17667000, 8558835, 8617375, 8668067, 8718561],
    'series_code' : ['SP.POP.TOTL', 'SP.POP.TOTL', 'SP.POP.TOTL', 'SP.POP.TOTL', 'SP.POP.TOTL', 'SP.POP.TOTL', 'SP.POP.TOTL', 'SP.POP.TOTL']}

gdp_aus_swe_dict = {
    'date' : ['1990-01-01 00:00:00', '1990-04-01 00:00:00', '1990-07-01 00:00:00', '1990-09-01 00:00:00', '1991-01-01 00:00:00', '1991-04-01 00:00:00', '1991-07-01 00:00:00', '1991-09-01 00:00:00', '1992-01-01 00:00:00', '1992-04-01 00:00:00', '1992-07-01 00:00:00', '1992-09-01 00:00:00', '1993-01-01 00:00:00', '1993-04-01 00:00:00', '1993-07-01 00:00:00', '1993-09-01 00:00:00', '1990-01-01 00:00:00', '1990-04-01 00:00:00', '1990-07-01 00:00:00', '1990-09-01 00:00:00', '1991-01-01 00:00:00', '1991-04-01 00:00:00', '1991-07-01 00:00:00', '1991-09-01 00:00:00', '1992-01-01 00:00:00', '1992-04-01 00:00:00', '1992-07-01 00:00:00', '1992-09-01 00:00:00', '1993-01-01 00:00:00', '1993-04-01 00:00:00', '1993-07-01 00:00:00', '1993-09-01 00:00:00'],
    'country' : ['Australia', 'Australia', 'Australia', 'Australia', 'Australia', 'Australia', 'Australia', 'Australia', 'Australia', 'Australia', 'Australia', 'Australia', 'Australia', 'Australia', 'Australia', 'Australia', 'Sweden', 'Sweden', 'Sweden', 'Sweden', 'Sweden', 'Sweden', 'Sweden', 'Sweden', 'Sweden', 'Sweden', 'Sweden', 'Sweden', 'Sweden', 'Sweden', 'Sweden', 'Sweden'],
    'gdp' : [158051.1324, 158263.5816, 157329.279, 158240.6781, 156195.9535, 155989.0327, 156635.8576, 156744.0566, 157916.0811, 159047.8271, 160658.176, 163960.2207, 165097.4951, 166027.059, 166203.1786, 169279.3479, 79837.84599, 80582.28597000001, 79974.36017, 80106.49738, 79524.24192, 79073.05901, 79084.77036000001, 79740.60625, 79390.92175, 79060.28297999999, 78904.60477, 76996.83684, 75783.58777, 76708.54823, 77662.01816, 77703.30364],
    'series_code' : ['NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD']}

df_gdp = pd.DataFrame(pop_dict)
df_pop = pd.DataFrame(gdp_aus_swe_dict)

display(df_gdp.head(3))
display(df_pop.head(3))
# Out:
#                   date    country       pop  series_code
# 0  1990-01-01 00:00:00  Australia  17065100  SP.POP.TOTL
# 1  1991-01-01 00:00:00  Australia  17284000  SP.POP.TOTL
# 2  1992-01-01 00:00:00  Australia  17495000  SP.POP.TOTL
#                   date    country          gdp    series_code
# 0  1990-01-01 00:00:00  Australia  158051.1324  NYGDPMKTPSAKD
# 1  1990-04-01 00:00:00  Australia  158263.5816  NYGDPMKTPSAKD
# 2  1990-07-01 00:00:00  Australia  157329.2790  NYGDPMKTPSAKD

# %%
# Merge gdp and pop on date and country with fill and notice rows 2 and 3
ctry_date = pd.merge_ordered(df_gdp, df_pop, on=['date', 'country'])
display(ctry_date.head(5))

ctry_date_fill = pd.merge_ordered(df_gdp, df_pop, on=['date', 'country'], fill_method='ffill')
display(ctry_date_fill.head(5))
# Out:
#                   date    country         pop series_code_x           gdp  \
# 0  1990-01-01 00:00:00  Australia  17065100.0   SP.POP.TOTL  158051.13240
# 1  1990-01-01 00:00:00     Sweden   8558835.0   SP.POP.TOTL   79837.84599
# 2  1990-04-01 00:00:00  Australia         NaN           NaN  158263.58160
# 3  1990-04-01 00:00:00     Sweden         NaN           NaN   80582.28597
# 4  1990-07-01 00:00:00  Australia         NaN           NaN  157329.27900
#
#    series_code_y
# 0  NYGDPMKTPSAKD
# 1  NYGDPMKTPSAKD
# 2  NYGDPMKTPSAKD
# 3  NYGDPMKTPSAKD
# 4  NYGDPMKTPSAKD
#                   date    country       pop series_code_x           gdp  \
# 0  1990-01-01 00:00:00  Australia  17065100   SP.POP.TOTL  158051.13240
# 1  1990-01-01 00:00:00     Sweden   8558835   SP.POP.TOTL   79837.84599
# 2  1990-04-01 00:00:00  Australia   8558835   SP.POP.TOTL  158263.58160
# 3  1990-04-01 00:00:00     Sweden   8558835   SP.POP.TOTL   80582.28597
# ...

# %% [markdown]
# ### **`merge_asof()`**
#
# it's is a Pandas function that can be used to merge two DataFrames based on the nearest values of a `key` column. It is particularly useful for merging **timeseries data**, where the values in the key column represent timestamps or dates.

# %%
import pandas as pd

# Create two sample DataFrames
df1 = pd.DataFrame({'time': pd.to_datetime(['2022-01-01 01:00:00', '2022-01-01 02:00:00', '2022-01-01 03:00:00', '2022-01-01 04:00:00', '2022-01-01 05:00:00']),
                    'value1': [10, 20, 30, 40, 50]})
df2 = pd.DataFrame({'time': pd.to_datetime(['2022-01-01 01:15:00', '2022-01-01 02:45:00', '2022-01-01 03:30:00', '2022-01-01 04:15:00']),
                    'value2': [100, 200, 300, 400]})

# Merge the two DataFrames using merge_asof()
merged_df = pd.merge_asof(df1, df2, on='time', direction='nearest')

# Print the merged DataFrame
print(merged_df)
# Out:
#                  time  value1  value2
# 0 2022-01-01 01:00:00      10     100
# 1 2022-01-01 02:00:00      20     100
# 2 2022-01-01 03:00:00      30     200
# 3 2022-01-01 04:00:00      40     400
# 4 2022-01-01 05:00:00      50     400

# %% [markdown]
# You attempt to track the price every five minutes. Still, due to some network latency, the prices you record are roughly every 5 minutes. You pull your price logs for three banks, `JP Morgan (JPM)`, `Wells Fargo (WFC)`, and `Bank Of America (BAC)`. You want to know how the price change of the two other banks compare to JP Morgan. Therefore, you will need to merge these three logs into one table. Afterward, you will use the pandas `.diff()` method to compute the price change over time. Finally, plot the price changes so you can review your analysis.

# %%
# JP Morgan (JPM)

jpm_dict = {
    'date_time' : ['2017-11-17 15:35:17', '2017-11-17 15:40:04', '2017-11-17 15:45:01', '2017-11-17 15:50:55', '2017-11-17 15:55:00', '2017-11-17 16:00:30', '2017-11-17 16:05:07', '2017-11-17 16:10:08', '2017-11-17 16:15:11', '2017-11-17 16:20:29', '2017-11-17 16:25:25', '2017-11-17 16:30:53', '2017-11-17 16:35:11', '2017-11-17 16:40:44', '2017-11-17 16:45:52', '2017-11-17 16:50:37', '2017-11-17 16:55:02'],
    'close' : [98.12, 98.18, 97.7307, 97.74, 97.815, 98.02, 97.8, 97.84, 97.71, 97.76, 97.82, 97.95, 97.99, 98.06, 98.05, 98.1101, 98.18]}

jpm = pd.DataFrame(jpm_dict)
jpm["date_time"] = pd.to_datetime(jpm["date_time"])
jpm.head(5)
# Out:
#             date_time    close
# 0 2017-11-17 15:35:17  98.1200
# 1 2017-11-17 15:40:04  98.1800
# 2 2017-11-17 15:45:01  97.7307
# 3 2017-11-17 15:50:55  97.7400
# 4 2017-11-17 15:55:00  97.8150

# %%
# Wells Fargo (WFC)
wells_dict = {
    'date_time' : ['2017-11-17 15:35:08', '2017-11-17 15:40:00', '2017-11-17 15:45:32', '2017-11-17 15:50:07', '2017-11-17 15:55:00', '2017-11-17 16:00:30', '2017-11-17 16:05:52', '2017-11-17 16:10:22', '2017-11-17 16:15:43', '2017-11-17 16:20:07', '2017-11-17 16:25:13', '2017-11-17 16:30:04', '2017-11-17 16:35:32', '2017-11-17 16:40:09', '2017-11-17 16:45:24', '2017-11-17 16:50:28', '2017-11-17 16:55:42'],
    'close': [54.3227, 54.32, 54.19, 54.17, 54.1841, 54.265, 54.2, 54.155, 54.19, 54.205, 54.23, 54.22, 54.22, 54.28, 54.24, 54.17, 54.18]
}

wells = pd.DataFrame(wells_dict)
wells["date_time"] = pd.to_datetime(wells["date_time"])
wells.head(5)
# Out:
#             date_time    close
# 0 2017-11-17 15:35:08  54.3227
# 1 2017-11-17 15:40:00  54.3200
# 2 2017-11-17 15:45:32  54.1900
# 3 2017-11-17 15:50:07  54.1700
# 4 2017-11-17 15:55:00  54.1841

# %%
# Bank Of America (BAC)
bac_dict = {
    'date_time' : ['2017-11-17 15:35:17', '2017-11-17 15:40:06', '2017-11-17 15:45:05', '2017-11-17 15:50:34', '2017-11-17 15:55:06', '2017-11-17 16:00:18', '2017-11-17 16:05:20', '2017-11-17 16:10:05', '2017-11-17 16:15:07', '2017-11-17 16:20:29', '2017-11-17 16:25:00', '2017-11-17 16:30:18', '2017-11-17 16:35:08', '2017-11-17 16:40:46', '2017-11-17 16:45:55', '2017-11-17 16:50:05', '2017-11-17 16:55:02'],
    'close' : [26.552, 26.552, 26.388, 26.378, 26.383000000000003, 26.451999999999998, 26.373, 26.388, 26.369, 26.388, 26.467, 26.482, 26.491999999999997, 26.526999999999997, 26.522, 26.546999999999997, 26.566999999999997]
}
bac = pd.DataFrame(bac_dict)
bac["date_time"] = pd.to_datetime(bac["date_time"])
bac.head(5)
# Out:
#             date_time   close
# 0 2017-11-17 15:35:17  26.552
# 1 2017-11-17 15:40:06  26.552
# 2 2017-11-17 15:45:05  26.388
# 3 2017-11-17 15:50:34  26.378
# 4 2017-11-17 15:55:06  26.383

# %%
# Use merge_asof() to merge jpm and wells
jpm_wells = pd.merge_asof(jpm, wells, on='date_time',
                          suffixes=('', '_wells'),
                          direction='nearest')

display(jpm_wells.head(2))   


# Use merge_asof() to merge jpm_wells and bac
jpm_wells_bac = pd.merge_asof(jpm_wells, bac, on='date_time',
                              suffixes=('_jpm', '_bac'),
                              direction='nearest')

display(jpm_wells_bac.head(2))   

#  it calculates the difference between an element and the element in the previous row (or column)
price_diffs = jpm_wells_bac.diff()
display(price_diffs.head(2))

# Plot the price diff of the close of jpm, wells and bac only
price_diffs.plot(y=['close_jpm', 'close_wells', 'close_bac'])
plt.show()
# Out:
#             date_time  close  close_wells
# 0 2017-11-17 15:35:17  98.12      54.3227
# 1 2017-11-17 15:40:04  98.18      54.3200
#             date_time  close_jpm  close_wells  close_bac
# 0 2017-11-17 15:35:17      98.12      54.3227     26.552
# 1 2017-11-17 15:40:04      98.18      54.3200     26.552
#         date_time  close_jpm  close_wells  close_bac
# 0             NaT        NaN          NaN        NaN
# 1 0 days 00:04:47       0.06      -0.0027        0.0

# %% [markdown]
# ### **Using `merge_asof()` to create dataset**

# %%
gdp_dict = {
    'date' : ['1979-01-01 00:00:00', '1979-04-01 00:00:00', '1979-07-01 00:00:00', '1979-10-01 00:00:00', '1980-01-01 00:00:00', '1980-04-01 00:00:00', '1980-07-01 00:00:00', '1980-10-01 00:00:00', '1981-01-01 00:00:00', '1981-04-01 00:00:00', '1981-07-01 00:00:00', '1981-10-01 00:00:00', '1982-01-01 00:00:00', '1982-04-01 00:00:00', '1982-07-01 00:00:00', '1982-10-01 00:00:00', '1983-01-01 00:00:00', '1983-04-01 00:00:00', '1983-07-01 00:00:00', '1983-10-01 00:00:00', '1984-01-01 00:00:00', '1984-04-01 00:00:00', '1984-07-01 00:00:00', '1984-10-01 00:00:00'],
    'gdp' : [2526.61, 2591.2470000000003, 2667.565, 2723.883, 2789.842, 2797.3520000000003, 2856.4829999999997, 2985.5570000000002, 3124.2059999999997, 3162.532, 3260.6090000000004, 3280.8179999999998, 3274.302, 3331.972, 3366.322, 3402.5609999999997, 3473.413, 3578.848, 3689.179, 3794.7059999999997, 3908.054, 4009.6009999999997, 4084.25, 4148.5509999999995]
}
gdp = pd.DataFrame(gdp_dict)   
gdp["date"] = pd.to_datetime(gdp["date"])


recession_dict = {
    'date' : ['1980-01-01 00:00:00', '1980-08-01 00:00:00', '1981-07-01 00:00:00', '1982-12-01 00:00:00', '1990-07-01 00:00:00', '1991-04-01 00:00:00', '2001-03-01 00:00:00', '2001-12-01 00:00:00', '2007-12-01 00:00:00', '2009-07-01 00:00:00'],
    'econ_status' : ['recession', 'normal', 'recession', 'normal', 'recession', 'normal', 'recession', 'normal', 'recession', 'normal']
}

recession = pd.DataFrame(recession_dict)
recession["date"] = pd.to_datetime(recession["date"])



# Merge gdp and recession on date using merge_asof()
gdp_recession = pd.merge_asof(gdp, recession, on='date')

# Create a list based on the row value of gdp_recession['econ_status']
is_recession = ['r' if s =='recession' else 'g' for s in gdp_recession['econ_status']]

# Plot a bar chart of gdp_recession
plt.style.use('ggplot')
gdp_recession.plot(kind='bar', y='gdp', x='date', color=is_recession, rot=90, figsize=(12, 5))
plt.show()

# %% [markdown]
# we can see from the chart that there were a number of quarters early in the `1980s` where a recession was an issue. `merge_asof()` allowed you to quickly add a flag to the `gdp` dataset by matching between two different dates, in one line of code!
#
# If you were to perform the same task using subsetting, it would have taken a lot more code.

# %% [markdown]
# ### **`merge_asof()` and `merge_ordered()` differences**
#
# | Feature| `merge_asof()` | `merge_ordered()` |
# | ------------- | ----------------------------------- | ----------------- |
# | Matching      | Matches on closest key              | Matches on exact key             |
# | Direction     | Forward or backward                 | Forward, backward, or nearest         |
# | Sorting       | Must be sorted on the key column(s) | Must be sorted on the key column(s)   |
# | Overlapping   | Overlapping values are included     | Overlapping values can be included/excluded depending on `fill_method` argument |
# | Interpolation | Can interpolate missing values      | Can interpolate missing values using `method` argument |
# | Output        | May have more rows than input       | Same number of rows as input           |

# %% [markdown]
# ### **Subsetting rows with `.query()`**

# %%
pop_dict = {
    'date' : ['1990-01-01 00:00:00', '1991-01-01 00:00:00', '1992-01-01 00:00:00', '1993-01-01 00:00:00', '1990-01-01 00:00:00', '1991-01-01 00:00:00', '1992-01-01 00:00:00', '1993-01-01 00:00:00'],
    'country' : ['Australia', 'Australia', 'Australia', 'Australia', 'Sweden', 'Sweden', 'Sweden', 'Sweden'],
    'pop' : [17065100, 17284000, 17495000, 17667000, 8558835, 8617375, 8668067, 8718561],
    'series_code' : ['SP.POP.TOTL', 'SP.POP.TOTL', 'SP.POP.TOTL', 'SP.POP.TOTL', 'SP.POP.TOTL', 'SP.POP.TOTL', 'SP.POP.TOTL', 'SP.POP.TOTL']}

gdp_aus_swe_dict = {
    'date' : ['1990-01-01 00:00:00', '1990-04-01 00:00:00', '1990-07-01 00:00:00', '1990-09-01 00:00:00', '1991-01-01 00:00:00', '1991-04-01 00:00:00', '1991-07-01 00:00:00', '1991-09-01 00:00:00', '1992-01-01 00:00:00', '1992-04-01 00:00:00', '1992-07-01 00:00:00', '1992-09-01 00:00:00', '1993-01-01 00:00:00', '1993-04-01 00:00:00', '1993-07-01 00:00:00', '1993-09-01 00:00:00', '1990-01-01 00:00:00', '1990-04-01 00:00:00', '1990-07-01 00:00:00', '1990-09-01 00:00:00', '1991-01-01 00:00:00', '1991-04-01 00:00:00', '1991-07-01 00:00:00', '1991-09-01 00:00:00', '1992-01-01 00:00:00', '1992-04-01 00:00:00', '1992-07-01 00:00:00', '1992-09-01 00:00:00', '1993-01-01 00:00:00', '1993-04-01 00:00:00', '1993-07-01 00:00:00', '1993-09-01 00:00:00'],
    'country' : ['Australia', 'Australia', 'Australia', 'Australia', 'Australia', 'Australia', 'Australia', 'Australia', 'Australia', 'Australia', 'Australia', 'Australia', 'Australia', 'Australia', 'Australia', 'Australia', 'Sweden', 'Sweden', 'Sweden', 'Sweden', 'Sweden', 'Sweden', 'Sweden', 'Sweden', 'Sweden', 'Sweden', 'Sweden', 'Sweden', 'Sweden', 'Sweden', 'Sweden', 'Sweden'],
    'gdp' : [158051.1324, 158263.5816, 157329.279, 158240.6781, 156195.9535, 155989.0327, 156635.8576, 156744.0566, 157916.0811, 159047.8271, 160658.176, 163960.2207, 165097.4951, 166027.059, 166203.1786, 169279.3479, 79837.84599, 80582.28597000001, 79974.36017, 80106.49738, 79524.24192, 79073.05901, 79084.77036000001, 79740.60625, 79390.92175, 79060.28297999999, 78904.60477, 76996.83684, 75783.58777, 76708.54823, 77662.01816, 77703.30364],
    'series_code' : ['NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD', 'NYGDPMKTPSAKD']}

gdp = pd.DataFrame(pop_dict)
pop = pd.DataFrame(gdp_aus_swe_dict)

# Merge gdp and pop on date and country with fill
gdp_pop = pd.merge_ordered(gdp, pop, on=['country','date'], fill_method='ffill')
display("Merging gdp and pop on date and country with fill", gdp_pop.head(5))
print("\n")

# Add a column named gdp_per_capita to gdp_pop that divides the gdp by pop
gdp_pop['gdp_per_capita'] = gdp_pop['gdp'] / gdp_pop['pop']

# Pivot data so gdp_per_capita, where index is date and columns is country
gdp_pivot = gdp_pop.pivot_table('gdp_per_capita', 'date', 'country')
display("Pivot data so gdp_per_capita, where index is date and columns is country", gdp_pivot.head(5))

# Select dates equal to or greater than 1991-01-01
recent_gdp_pop = gdp_pivot.query('date >= "1991-01-01"')

# Plot recent_gdp_pop
plt.style.use('ggplot')
recent_gdp_pop.plot(rot=90)
plt.show()
# Out:
# 'Merging gdp and pop on date and country with fill'
#                   date    country       pop series_code_x          gdp  \
# 0  1990-01-01 00:00:00  Australia  17065100   SP.POP.TOTL  158051.1324
# 1  1990-04-01 00:00:00  Australia  17065100   SP.POP.TOTL  158263.5816
# 2  1990-07-01 00:00:00  Australia  17065100   SP.POP.TOTL  157329.2790
# 3  1990-09-01 00:00:00  Australia  17065100   SP.POP.TOTL  158240.6781
# 4  1991-01-01 00:00:00  Australia  17284000   SP.POP.TOTL  156195.9535
#
#    series_code_y
# 0  NYGDPMKTPSAKD
# 1  NYGDPMKTPSAKD
# 2  NYGDPMKTPSAKD
# 3  NYGDPMKTPSAKD
# 4  NYGDPMKTPSAKD
# 'Pivot data so gdp_per_capita, where index is date and columns is country'
# country              Australia    Sweden
# date
# 1990-01-01 00:00:00   0.009262  0.009328
# 1990-04-01 00:00:00   0.009274  0.009415
# 1990-07-01 00:00:00   0.009219  0.009344
# 1990-09-01 00:00:00   0.009273  0.009360
# 1991-01-01 00:00:00   0.009037  0.009228

# %% [markdown]
# we can see from the plot that the `per capita GDP` of `Australia` passed `Sweden` in `1992`. By using the `.query()` method, you were able to select the appropriate rows easily. The `.query()` method is easy to read and straightforward.

# %%
# Example of an Pivot Table
import seaborn as sns

# Load Titanic dataset
titanic_df = sns.load_dataset('titanic')

# Create pivot table
pivot_table = titanic_df.pivot_table(
    values='survived', 
    index='sex', 
    columns='class', 
    aggfunc='mean'
)

print(pivot_table)
# Out:
# class      First    Second     Third
# sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %% [markdown]
# ### **Using `.melt()` to reshape government data**
#
#
# `pandas.melt()` is used to reshape your data  from wide to long **for easier analysis or visualization**.
#
#
# ```python
# pandas.melt(frame, id_vars=None, value_vars=None, var_name=None, value_name='value', col_level=None, ignore_index=Tr
# ```

# %% [markdown]
# Pandas`.melt()` is a function that can be used to transform a DataFrame from **wide format to long format**.
#
# It is useful for converting a DataFrame into a format where one or more columns are identifier variables (`id_vars`), while all other columns, considered measured variables (`value_vars`), are `unpivoted` to the row axis, leaving just two non-identifier columns, `variable` and `value`.

# %%
# Create a sample DataFrame
df = pd.DataFrame({'A': {0: 'a', 1: 'b', 2: 'c'},
                   'B': {0: 1, 1: 3, 2: 5},
                   'C': {0: 2, 1: 4, 2: 6}})
display(df)

# Melt the DataFrame
melted_df = pd.melt(df, id_vars=['A'], value_vars=['B', 'C'])

# Print the melted DataFrame
display(melted_df)
# Out:
#    A  B  C
# 0  a  1  2
# 1  b  3  4
# 2  c  5  6
#    A variable  value
# 0  a        B      1
# 1  b        B      3
# 2  c        B      5
# 3  a        C      2
# 4  b        C      4
# 5  c        C      6

# %% [markdown]
# In this example, we specify `column A` as the `identifier variable` (`id_vars`) and `columns B` and `C` as the `measured variables` (`value_vars`). The resulting melted DataFrame has three columns: `A`, `variable`, and `value`. The variable column contains the column names from the original DataFrame (`B` and `C`) and the value column contains the corresponding values.

# %%
import pandas as pd

# Create a sample DataFrame
df = pd.DataFrame({'A': {0: 'a', 1: 'b', 2: 'c'},
                   'B': {0: 1, 1: 3, 2: 5},
                   'C': {0: 2, 1: 4, 2: 6}})

# Melt the DataFrame
melted_df = pd.melt(df, id_vars=['A'], value_vars=['B', 'C'], var_name='Variable', value_name='Value')

# Print the melted DataFrame
display(melted_df)
# Out:
#    A Variable  Value
# 0  a        B      1
# 1  b        B      3
# 2  c        B      5
# 3  a        C      2
# 4  b        C      4
# 5  c        C      6

# %%
ur_wide_dict = {
    'year': ['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020'],
    'jan': [9.8, 9.1, 8.3, 8.0, 6.6, 5.7, 4.9, 4.7, 4.1, 4.0, 3.6],
    'feb' : [9.8, 9.0, 8.3, 7.7, 6.7, 5.5, 4.9, 4.6, 4.1, 3.8, 3.5],
    'mar' : [9.9, 9.0, 8.2, 7.5, 6.7, 5.4, 5.0, 4.4, 4.0, 3.8, 4.4],
    'apr': [9.9, 9.1, 8.2, 7.6, 6.2, 5.4, 5.0, 4.4, 4.0, 3.6, np.nan],
    'may': [9.6, 9.0, 8.2, 7.5, 6.3, 5.6, 4.8, 4.4, 3.8, 3.6, np.nan],
    'jun':[9.4, 9.1, 8.2, 7.5, 6.1, 5.3, 4.9, 4.3, 4.0, 3.7, np.nan],
    'jul':[9.4, 9.0, 8.2, 7.3, 6.2, 5.2, 4.8, 4.3, 3.8, 3.7, np.nan],
    'aug':[9.5, 9.0, 8.1, 7.2, 6.1, 5.1, 4.9, 4.4, 3.8, 3.7, np.nan],
    'sep': [9.5, 9.0, 7.8, 7.2, 5.9, 5.0, 5.0, 4.2, 3.7, 3.5, np.nan],
    'oct' :[9.4, 8.8, 7.8, 7.2, 5.7, 5.0, 4.9, 4.1, 3.8, 3.6, np.nan],
    'nov':[9.8, 8.6, 7.7, 6.9, 5.8, 5.1, 4.7, 4.2, 3.7, 3.5, np.nan],
    'dec':[9.3, 8.5, 7.9, 6.7, 5.6, 5.0, 4.7, 4.1, 3.9, 3.5, np.nan]
}

ur_wide = pd.DataFrame(ur_wide_dict)
ur_wide
# Out:
#     year  jan  feb  mar  apr  may  jun  jul  aug  sep  oct  nov  dec
# 0   2010  9.8  9.8  9.9  9.9  9.6  9.4  9.4  9.5  9.5  9.4  9.8  9.3
# 1   2011  9.1  9.0  9.0  9.1  9.0  9.1  9.0  9.0  9.0  8.8  8.6  8.5
# 2   2012  8.3  8.3  8.2  8.2  8.2  8.2  8.2  8.1  7.8  7.8  7.7  7.9
# 3   2013  8.0  7.7  7.5  7.6  7.5  7.5  7.3  7.2  7.2  7.2  6.9  6.7
# 4   2014  6.6  6.7  6.7  6.2  6.3  6.1  6.2  6.1  5.9  5.7  5.8  5.6
# 5   2015  5.7  5.5  5.4  5.4  5.6  5.3  5.2  5.1  5.0  5.0  5.1  5.0
# 6   2016  4.9  4.9  5.0  5.0  4.8  4.9  4.8  4.9  5.0  4.9  4.7  4.7
# 7   2017  4.7  4.6  4.4  4.4  4.4  4.3  4.3  4.4  4.2  4.1  4.2  4.1
# 8   2018  4.1  4.1  4.0  4.0  3.8  4.0  3.8  3.8  3.7  3.8  3.7  3.9
# 9   2019  4.0  3.8  3.8  3.6  3.6  3.7  3.7  3.7  3.5  3.6  3.5  3.5
# 10  2020  3.6  3.5  4.4  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN

# %% [markdown]
# `wide` to `long` **for easier analysis or visualization**.

# %%
# Unpivot everything besides the year column
ur_long = ur_wide.melt(id_vars=['year'], var_name='month', value_name='unempl_rate')
display(ur_long.head(5))

# Create a date column using the month and year columns of ur_long
ur_long['date'] = pd.to_datetime(ur_long['month'] + '-' + ur_long['year'].astype(str))

# Sort ur_long by date in ascending order
ur_sorted = ur_long.sort_values('date')

# Plot the unempl_rate by date
ur_sorted.plot(x='date', y='unempl_rate')
plt.show()
# Out:
#    year month  unempl_rate
# 0  2010   jan          9.8
# 1  2011   jan          9.1
# 2  2012   jan          8.3
# 3  2013   jan          8.0
# 4  2014   jan          6.6

# %% [markdown]
# The plot shows a steady decrease in the unemployment rate with an increase near the end. This increase is likely the effect of the `COVID-19` pandemic and its impact on shutting down most of the US economy. In general, data is often provided (_especially by governments_) in a format that is easily read by people but not by machines. The `.melt()` method is a handy tool for reshaping data into a useful form.

# %% [markdown]
# ### **Using `.melt()` for stocks vs bond performance**

# %%
from collections import namedtuple

ten_yr = pd.DataFrame(index = [0, 1, 2, 3],columns = ['metric', '2007-02-01', '2007-03-01', '2007-04-01', '2007-05-01', '2007-06-01', '2007-07-01', '2007-08-01', '2007-09-01', '2007-10-01', '2007-11-01', '2007-12-01', '2008-01-01', '2008-02-01', '2008-03-01', '2008-04-01', '2008-05-01', '2008-06-01', '2008-07-01', '2008-08-01', '2008-09-01', '2008-10-01', '2008-11-01', '2008-12-01', '2009-01-01', '2009-02-01', '2009-03-01', '2009-04-01', '2009-05-01', '2009-06-01', '2009-07-01', '2009-08-01', '2009-09-01', '2009-10-01', '2009-11-01', '2009-12-01'])


ten_yr.iloc[0] = ['open', 0.033490769, -0.060448691, 0.025425602000000002, -0.004312204, 0.060632307999999996, 0.02715394, -0.059232757000000004, -0.046270864, 0.014399646, -0.027080148999999998, -0.114702581, 0.022565922999999998, -0.09447061699999999, -0.024644031, -0.021336327999999998, 0.07601835900000001, 0.073047187, -0.020621118, 0.0, -0.024099442000000002, -0.025734338, 0.05042689400000001, -0.267716535, -0.23586541800000002, 0.285973672, 0.045887752000000004, -0.102598718, 0.191049267, 0.10672560800000001, 0.023965762999999998, -0.006687099, -0.046563815, -0.032068255, 0.034346505, -0.050543637999999995]
ten_yr.iloc[1] = ['high', -0.007337954, -0.040657083999999996, 0.022046233, 0.030575916, 0.08026823799999999, -0.021632807, -0.059796193, -0.038445808, 0.003615483, -0.055520237, -0.039488445, -0.053492175, -0.022704837000000002, -0.064646465, 0.049676026, 0.064557613, 0.044696787, -0.034690102, -0.020124581000000002, -0.045232274, 0.052240717, -0.035288391, -0.27169525699999997, -0.01073779, 0.06932773099999999, -0.004256713, 0.04110490000000001, 0.186986734, 0.068121341, -0.061783757, 0.031864047, -0.090324241, 0.012446958999999999, -0.004191115, 0.099326599]
ten_yr.iloc[2] = ['low', -0.016146629, -0.007984032, 0.031075341, -0.0021682570000000003, 0.059104737000000004, -0.027287649, -0.051676861, -0.043371886, 0.002557545, -0.10830241199999999, -0.00130039, -0.145572917, 0.074672356, -0.067498582, 0.043187348, 0.073469388, 0.047256926, -0.022562241, -0.001591934, -0.13632739800000002, 0.046153846, -0.138235294, -0.30443686, 0.059371932999999995, 0.21723019899999998, -0.062404870999999994, 0.068993506, 0.16818527, 0.12317192099999999, -0.055266204000000006, 0.039509954, -0.035945787, -0.050733495999999996, 0.030264005, 0.0071875]
ten_yr.iloc[3] = ['close', -0.05719022, 0.021538462, -0.003872633, 0.056155508, 0.029243354, -0.052056427999999995, -0.049046322, 0.009257218000000001, -0.022712383, -0.112402235, 0.015861027, -0.098141264, -0.028854081, -0.028862479, 0.09527972, 0.076350093, -0.016559565, 0.0, -0.041719025, 0.00367165, 0.037366083, -0.25516372800000003, -0.24112276, 0.267379679, 0.069268636, -0.11706675400000001, 0.163500931, 0.10915493, 0.016738817, -0.006244678, -0.028563268, -0.02763893, 0.025703054, -0.056308962000000004, 0.200562324]

# US 10-year treasury bond price
ten_yr
# Out:
#   metric 2007-02-01 2007-03-01 2007-04-01 2007-05-01 2007-06-01 2007-07-01  \
# 0   open   0.033491  -0.060449   0.025426  -0.004312   0.060632   0.027154
# 1   high  -0.007338  -0.040657   0.022046   0.030576   0.080268  -0.021633
# 2    low  -0.016147  -0.007984   0.031075  -0.002168   0.059105  -0.027288
# 3  close   -0.05719   0.021538  -0.003873   0.056156   0.029243  -0.052056
#
#   2007-08-01 2007-09-01 2007-10-01  ... 2009-03-01 2009-04-01 2009-05-01  \
# 0  -0.059233  -0.046271     0.0144  ...   0.045888  -0.102599   0.191049
# 1  -0.059796  -0.038446   0.003615  ...  -0.004257   0.041105   0.186987
# 2  -0.051677  -0.043372   0.002558  ...  -0.062405   0.068994   0.168185
# 3  -0.049046   0.009257  -0.022712  ...  -0.117067   0.163501   0.109155
#
#   2009-06-01 2009-07-01 2009-08-01 2009-09-01 2009-10-01 2009-11-01 2009-12-01
# 0   0.106726   0.023966  -0.006687  -0.046564  -0.032068   0.034347  -0.050544
# ...

# %%
data  = {'date'  : ['2007-02-01', '2007-03-01', '2007-04-01', '2007-05-01', '2007-06-01', '2007-07-01', '2007-08-01', '2007-09-01', '2007-10-01', '2007-11-01', '2007-12-01', '2008-01-01', '2008-02-01', '2008-03-01', '2008-04-01', '2008-05-01', '2008-06-01', '2008-07-01', '2008-08-01', '2008-09-01', '2008-10-01', '2008-11-01', '2008-12-01', '2009-01-01', '2009-02-01', '2009-03-01', '2009-04-01', '2009-05-01', '2009-06-01', '2009-07-01', '2009-08-01', '2009-09-01', '2009-10-01', '2009-11-01', '2009-12-01', '2010-01-01', '2010-02-01', '2010-03-01', '2010-04-01', '2010-05-01', '2010-06-01', '2010-07-01', '2010-08-01', '2010-09-01', '2010-10-01', '2010-11-01', '2010-12-01', '2011-01-01', '2011-02-01', '2011-03-01', '2011-04-01', '2011-05-01', '2011-06-01', '2011-07-01', '2011-08-01', '2011-09-01', '2011-10-01', '2011-11-01', '2011-12-01', '2012-01-01', '2012-02-01', '2012-03-01', '2012-04-01', '2012-05-01', '2012-06-01', '2012-07-01', '2012-08-01', '2012-09-01', '2012-10-01', '2012-11-01', '2012-12-01', '2013-01-01', '2013-02-01', '2013-03-01', '2013-04-01', '2013-05-01', '2013-06-01', '2013-07-01', '2013-08-01', '2013-09-01', '2013-10-01', '2013-11-01', '2013-12-01', '2014-01-01', '2014-02-01', '2014-03-01', '2014-04-01', '2014-05-01', '2014-06-01', '2014-07-01', '2014-08-01', '2014-09-01', '2014-10-01', '2014-11-01', '2014-12-01', '2015-01-01', '2015-02-01', '2015-03-01', '2015-04-01', '2015-05-01', '2015-06-01', '2015-07-01', '2015-08-01', '2015-09-01', '2015-10-01', '2015-11-01', '2015-12-01', '2016-01-01', '2016-02-01', '2016-03-01', '2016-04-01', '2016-05-01', '2016-06-01', '2016-07-01', '2016-08-01', '2016-09-01', '2016-10-01', '2016-11-01', '2016-12-01', '2017-01-01', '2017-02-01', '2017-03-01', '2017-04-01', '2017-05-01', '2017-06-01', '2017-07-01', '2017-08-01', '2017-09-01', '2017-10-01', '2017-11-01', '2017-12-01', '2018-01-01', '2018-02-01', '2018-03-01', '2018-04-01', '2018-05-01', '2018-06-01', '2018-07-01', '2018-08-01', '2018-09-01', '2018-10-01', '2018-11-01', '2018-12-01', '2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01', '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01', '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01', '2020-01-01', '2020-02-01', '2020-03-01', '2020-04-01'],
         'close' : [0.005094385, -0.02613902, 0.04852522, 0.052007442, -0.016070328000000002, 0.038005504, -0.063894742, 0.066521287, 0.002475632, -0.024041665, -0.01062883, -0.059491712999999995, -0.035595773, 0.013213023, 0.020871591999999998, -0.00143428, -0.042702328, -0.057398135, 0.025433807000000003, -0.069100093, -0.15418084599999998, -0.080309949, 0.058127134000000004, -0.037496447999999995, -0.16479474300000002, 0.042397187999999995, 0.064512765, 0.05677603, 0.038969204, -0.047834178, 0.11097163, 0.05759352, -0.007827874, 0.07739017599999999, -0.003478498, -0.022410836, 0.012850318999999999, 0.050855723, 0.01551093, -0.080054868, -0.035769399, 0.078133736, -0.034476195, 0.067414235, 0.023774684, -0.002383415, 0.039776433, 0.031101532, 0.014329031, -0.0021388789999999998, 0.032418077999999996, 0.001198984, -0.002194236, 0.002626051, -0.06695646, -0.03640589, 0.025681987000000003, 0.001359161, 0.045912125, 0.052597849, 0.017741846000000002, 0.025919756000000002, -0.009181033, -0.053259198, 0.034768257000000004, -0.00014041799999999998, 0.0350163, 0.024247324, -0.018273602, -0.026968932, 0.011859747, 0.028023244, 0.036520977999999996, 0.023491879, 0.037377411, 0.016851552, -0.000224894, 0.025628287000000003, -0.042491667999999996, 0.028118227000000003, 0.007576228000000001, 0.032678999, 0.018379701000000002, 0.015901757, -0.014940513, 0.014771536000000002, 0.007107820999999999, 0.010994522, 0.006544182, -0.993017009, 144.5183012, -0.003245918, 0.020395567, 0.025168869, -0.000286042, -0.03692956, 0.056382432, -0.019666107, 0.014750208, -0.0015301639999999999, -0.021720378999999998, 0.006379318, -0.067894606, -0.025750218, 0.096948254, 0.003193047, -0.016642328, -0.055018607000000004, 0.003048603, 0.070753465, 0.0050042129999999995, 0.000765158, 0.008028289000000001, 0.02800888, -0.001698052, -0.005037860999999999, -0.009055988000000001, 0.054083208, 0.033414211, 0.005135964, 0.047729302, -0.007159263000000001, 0.013420031, 0.0032568090000000003, 0.01622663, 0.025363472999999997, 0.002603798, 0.020821848, 0.04338742599999999, 0.038293773999999996, 0.01840769, 0.057857909000000006, -0.042838503, -0.034663499, 6.208199999999999e-05, 0.010458144, -0.005914219, 0.047125374000000005, 0.021624917, 0.019006501000000002, -0.05074022, 0.016830012, -0.08657517099999999, 0.071683602, 0.036652472, 0.000490015, 0.025616447999999997, -0.066856205, 0.07810595299999999, np.nan, np.nan, np.nan, 0.006778502, np.nan, np.nan, np.nan, -0.010447310999999999, -0.216145511, 0.034803753]
         }

dji = pd.DataFrame(data)
dji
# Out:
#            date     close
# 0    2007-02-01  0.005094
# 1    2007-03-01 -0.026139
# 2    2007-04-01  0.048525
# 3    2007-05-01  0.052007
# 4    2007-06-01 -0.016070
# ..          ...       ...
# 154  2019-12-01       NaN
# 155  2020-01-01       NaN
# 156  2020-02-01 -0.010447
# 157  2020-03-01 -0.216146
# 158  2020-04-01  0.034804
#
# [159 rows x 2 columns]

# %%
# Use melt on ten_yr, unpivot everything besides the metric column
bond_perc = ten_yr.melt(id_vars='metric', var_name='date', value_name='close')

# Use query on bond_perc to select only the rows where metric=close
bond_perc_close = bond_perc.query('metric == "close"')

# Merge (ordered) dji and bond_perc_close on date with an inner join
dow_bond = pd.merge_ordered(dji, bond_perc_close, on='date',
                            suffixes=('_dow', '_bond'), how='inner')

# Plot only the close_dow and close_bond columns
dow_bond.plot(y=['close_dow', 'close_bond'], x='date', rot=90)
plt.show()

# %% [markdown]
#  The plot confirms that the bond and stock prices are inversely correlated. Often as the price of stocks increases, the price for bonds decreases.

# %% [markdown]
# <p align='center'>
#   <a href="#"><img src='https://tymsai.netlify.app/resource/1.gif' height='10' width=100% alt="div"></a>
# </p>
#
# #### $\color{skyblue}{\textbf{Connect with me:}}$
#
#
# [<img align="left" src="https://cdn4.iconfinder.com/data/icons/social-media-icons-the-circle-set/48/twitter_circle-512.png" width="32px"/>][twitter]
# [<img align="left" src="https://cdn-icons-png.flaticon.com/512/145/145807.png" width="32px"/>][linkedin]
# [<img align="left" src="https://cdn2.iconfinder.com/data/icons/whcompare-blue-green-web-hosting-1/425/cdn-512.png" width="32px"/>][Portfolio]
#
# [twitter]: https://twitter.com/F4izy
# [linkedin]: https://www.linkedin.com/in/mohd-faizy/
# [Portfolio]: https://mohdfaizy.com/
